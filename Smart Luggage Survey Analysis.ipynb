# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inpPath = "C:/CarolineZiegler/Studium_DCU/8. Semester/Business Analytics Portfolio/Portfolio/02_Uni Projects/"
NED_Df = pd.read_csv(inpPath + "Blank Quiz.csv", delimiter = ",")
NED_Df
# Out:
#                       Timestamp  How old are you?  \
# 0     2023/11/12 7:06:55 pm CET                21
# 1     2023/11/12 7:08:55 pm CET                22
# 2     2023/11/12 7:09:26 pm CET                25
# 3     2023/11/12 7:10:46 pm CET                22
# 4     2023/11/12 7:22:38 pm CET                61
# ..                          ...               ...
# 229  2023/11/17 10:40:01 pm CET                51
# 230   2023/11/21 8:22:35 am CET                23
# 231  2023/11/21 11:29:31 am CET                22
# 232  2023/11/21 12:49:31 pm CET                22
# 233   2023/11/21 1:06:06 pm CET                23
#
#     What is your nationality (nationalities)?  \
# 0                                    Belgian
# 1                                      german
# 2                               German, Swiss
# 3                                      German
# 4                                      German
# ..                                        ...
# 229                                    German
# 230                                   German
# 231                                    German
# 232                                     Swiss
# 233                                 Sri Lanka
#
#     Where do you currently reside (city and country)?  \
# 0                                    Dublin, Ireland
# 1                                     Dublin, Ireland
# 2                                             Ireland
# 3                                     Dublin, Ireland
# 4                                  Kirchentellinsfurt
# ..                                                ...
# 229                                   Valencia, Spain
# 230                                 Tübingen Germany
# 231                                           Germany
# 232                                Basel, Switzerland
# 233                                 Olten Switzerland
#
#     What is your occupation?  \
# 0                   Student
# 1                   Student
# 2                    Student
# 3                    Student
# 4              Civilengineer
# ..                       ...
# 229                    None
# 230                 Student
# 231                  Student
# 232                  Student
# 233                  Student
#
#     How often do you travel per year (by airline, train, bus, etc.)?  \
# 0                                   More than 15 times
# 1                                   More than 15 times
# 2                                                  4-6
# 3                                   More than 15 times
# 4                                                  1-3
# ..                                                 ...
# 229                                                4-6
# 230                                              10-15
# 231                                                4-6
# 232                                                1-3
# 233                                                1-3
#
#     What type of luggage do you use when travelling? (multiple answers possible)  \
# 0    Suitcase (carry-on);Suitcase (check-in luggage...
# 1    Suitcase (carry-on);Suitcase (check-in luggage...
# 2    Suitcase (carry-on);Suitcase (check-in luggage...
# 3    Suitcase (carry-on);Suitcase (check-in luggage...
# 4               Suitcase (check-in luggage);Laptop bag
# ..                                                 ...
# 229  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230  Suitcase (carry-on);Backpack (below 50 litre);...
# 231  Suitcase (carry-on);Suitcase (check-in luggage...
# 232  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                        Suitcase (check-in luggage)
#
#     Do you use bulky luggage and if so, for what items?  \
# 0        No, I don’t use bulky luggage when traveling
# 1                                                  NaN
# 2                                                   No
# 3                                                  NaN
# 4                                                   No
# ..                                                 ...
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                            Clothes
#
#     Do you plan to buy a new piece of luggage in the next year?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                 No
# 231                                                 No
# 232                                                 No
# 233                                                 No
#
#     If yes, what type of luggage and why?  \
# 0                                       /
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 229                                   NaN
# 230                                   NaN
# 231                                   NaN
# 232                                   NaN
# 233                                   NaN
#
#     Have you ever had to repack your luggage because you exceeded the weight limit?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 229                                                Yes
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
#
#     Have you ever left behind your luggage somewhere when travelling?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                Yes
# 231                                                 No
# 232                                                 No
# 233                                                 No
#
#     Has your luggage ever been misplaced by an airline?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                  Yes
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 229                                                Yes
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                 No
#
#     Do you own any smart luggage?  \
# 0                              No
# 1                              No
# 2                              No
# 3                              No
# 4                              No
# ..                            ...
# 229                            No
# 230                           Yes
# 231                            No
# 232                            No
# 233                            No
#
#     If yes, which smart luggage do you own and why did you buy it?   \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#     If no, what currently prevents you from purchasing a smart luggage?  \
# 0    The pieces of luggage I own still have a lot o...
# 1                     Price, Design, weight of luggage
# 2                 Currently no smart hiking backpacks
# 3    Only one feature per solution and too expensiv...
# 4                                              No time
# ..                                                 ...
# 229                                  What's the point?
# 230                                                NaN
# 231                                                NaN
# 232  Because I think that I don’t travel enough to ...
# 233                       I dont need it at the moment
#
#     Do you own and use an AirTag or similar tracking device when travelling?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                 No
# 231                                                Yes
# 232                                                 No
# 233                                                 No
#
#     What would enhance your travel experience when travelling with luggage (e.g. tracking device, integrated scale)?  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#     What are your biggest concern(s)/fear(s) when travelling with luggage?  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     How much would you be willing to pay for such a solution?
# 0                                                31-45
# 1                                                61-75
# 2                                                46-60
# 3                                                46-60
# 4                                                31-45
# ..                                                 ...
# 229                    I would not buy such a solution
# 230                                            31-45 €
# 231                                            16-30 €
# 232                                           76-100 €
# 233                                            31-45 €
#
# [234 rows x 20 columns]

# %%
NED_Df.drop("Timestamp", inplace = True, axis =1)
NED_Df
# Out:
#      How old are you? What is your nationality (nationalities)?  \
# 0                  21                                  Belgian
# 1                  22                                    german
# 2                  25                             German, Swiss
# 3                  22                                    German
# 4                  61                                    German
# ..                ...                                       ...
# 229                51                                    German
# 230                23                                   German
# 231                22                                    German
# 232                22                                     Swiss
# 233                23                                 Sri Lanka
#
#     Where do you currently reside (city and country)?  \
# 0                                    Dublin, Ireland
# 1                                     Dublin, Ireland
# 2                                             Ireland
# 3                                     Dublin, Ireland
# 4                                  Kirchentellinsfurt
# ..                                                ...
# 229                                   Valencia, Spain
# 230                                 Tübingen Germany
# 231                                           Germany
# 232                                Basel, Switzerland
# 233                                 Olten Switzerland
#
#     What is your occupation?  \
# 0                   Student
# 1                   Student
# 2                    Student
# 3                    Student
# 4              Civilengineer
# ..                       ...
# 229                    None
# 230                 Student
# 231                  Student
# 232                  Student
# 233                  Student
#
#     How often do you travel per year (by airline, train, bus, etc.)?  \
# 0                                   More than 15 times
# 1                                   More than 15 times
# 2                                                  4-6
# 3                                   More than 15 times
# 4                                                  1-3
# ..                                                 ...
# 229                                                4-6
# 230                                              10-15
# 231                                                4-6
# 232                                                1-3
# 233                                                1-3
#
#     What type of luggage do you use when travelling? (multiple answers possible)  \
# 0    Suitcase (carry-on);Suitcase (check-in luggage...
# 1    Suitcase (carry-on);Suitcase (check-in luggage...
# 2    Suitcase (carry-on);Suitcase (check-in luggage...
# 3    Suitcase (carry-on);Suitcase (check-in luggage...
# 4               Suitcase (check-in luggage);Laptop bag
# ..                                                 ...
# 229  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230  Suitcase (carry-on);Backpack (below 50 litre);...
# 231  Suitcase (carry-on);Suitcase (check-in luggage...
# 232  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                        Suitcase (check-in luggage)
#
#     Do you use bulky luggage and if so, for what items?  \
# 0        No, I don’t use bulky luggage when traveling
# 1                                                  NaN
# 2                                                   No
# 3                                                  NaN
# 4                                                   No
# ..                                                 ...
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                            Clothes
#
#     Do you plan to buy a new piece of luggage in the next year?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                 No
# 231                                                 No
# 232                                                 No
# 233                                                 No
#
#     If yes, what type of luggage and why?  \
# 0                                       /
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 229                                   NaN
# 230                                   NaN
# 231                                   NaN
# 232                                   NaN
# 233                                   NaN
#
#     Have you ever had to repack your luggage because you exceeded the weight limit?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 229                                                Yes
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                Yes
#
#     Have you ever left behind your luggage somewhere when travelling?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                  Yes
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                Yes
# 231                                                 No
# 232                                                 No
# 233                                                 No
#
#     Has your luggage ever been misplaced by an airline?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                  Yes
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 229                                                Yes
# 230                                                Yes
# 231                                                Yes
# 232                                                Yes
# 233                                                 No
#
#     Do you own any smart luggage?  \
# 0                              No
# 1                              No
# 2                              No
# 3                              No
# 4                              No
# ..                            ...
# 229                            No
# 230                           Yes
# 231                            No
# 232                            No
# 233                            No
#
#     If yes, which smart luggage do you own and why did you buy it?   \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#     If no, what currently prevents you from purchasing a smart luggage?  \
# 0    The pieces of luggage I own still have a lot o...
# 1                     Price, Design, weight of luggage
# 2                 Currently no smart hiking backpacks
# 3    Only one feature per solution and too expensiv...
# 4                                              No time
# ..                                                 ...
# 229                                  What's the point?
# 230                                                NaN
# 231                                                NaN
# 232  Because I think that I don’t travel enough to ...
# 233                       I dont need it at the moment
#
#     Do you own and use an AirTag or similar tracking device when travelling?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 229                                                 No
# 230                                                 No
# 231                                                Yes
# 232                                                 No
# 233                                                 No
#
#     What would enhance your travel experience when travelling with luggage (e.g. tracking device, integrated scale)?  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#     What are your biggest concern(s)/fear(s) when travelling with luggage?  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     How much would you be willing to pay for such a solution?
# 0                                                31-45
# 1                                                61-75
# 2                                                46-60
# 3                                                46-60
# 4                                                31-45
# ..                                                 ...
# 229                    I would not buy such a solution
# 230                                            31-45 €
# 231                                            16-30 €
# 232                                           76-100 €
# 233                                            31-45 €
#
# [234 rows x 19 columns]

# %%
NED_Df.columns
# Out:
# Index(['How old are you?', 'What is your nationality (nationalities)?',
#        'Where do you currently reside (city and country)?',
#        'What is your occupation?',
#        'How often do you travel per year (by airline, train, bus, etc.)?',
#        'What type of luggage do you use when travelling? (multiple answers possible)',
#        'Do you use bulky luggage and if so, for what items?',
#        'Do you plan to buy a new piece of luggage in the next year?',
#        'If yes, what type of luggage and why?',
#        'Have you ever had to repack your luggage because you exceeded the weight limit?',
#        'Have you ever left behind your luggage somewhere when travelling?',
#        'Has your luggage ever been misplaced by an airline?',
#        'Do you own any smart luggage?',
#        'If yes, which smart luggage do you own and why did you buy it? ',
#        'If no, what currently prevents you from purchasing a smart luggage?',
#        'Do you own and use an AirTag or similar tracking device when travelling?',
#        'What would enhance your travel experience when travelling with luggage (e.g. tracking device, integrated scale)?',
#        'What are your biggest concern(s)/fear(s) when travelling with luggage?',
#        'How much would you be willing to pay for such a solution?'],
#       dtype='object')

# %%
NED_Df.rename(columns = {"How old are you?": "Age", 
                         "What is your nationality (nationalities)?":"Nationality", 
                         "Where do you currently reside (city and country)?": "Current Residence",
                         "What is your occupation?": "Occupation",
                         "How often do you travel per year (by airline, train, bus, etc.)?":"Travel per year", 
                         "What type of luggage do you use when travelling? (multiple answers possible)":"Travel Luggage", 
                         "Do you use bulky luggage and if so, for what items?":"Bulky Luggage", 
                         "Do you plan to buy a new piece of luggage in the next year?":"Luggage Buying Plans (next year)", 
                         "If yes, what type of luggage and why?":"Plan-to-buy Luggage", 
                         "Have you ever had to repack your luggage because you exceeded the weight limit?":"Repacking Luggage", 
                         "Have you ever left behind your luggage somewhere when travelling?": "Forgotten luggage", 
                         "Has your luggage ever been misplaced by an airline?":"Misplaced Luggage by Airlines", 
                         "Do you own any smart luggage?":"Smart Luggage Owner", 
                         "If yes, which smart luggage do you own and why did you buy it? ":"Kind of Smart Luggage", 
                         "If no, what currently prevents you from purchasing a smart luggage?":"Prevention from Buying Smart Luggage", 
                         "Do you own and use an AirTag or similar tracking device when travelling?":"AirTag Users", 
                         "What would enhance your travel experience when travelling with luggage (e.g. tracking device, integrated scale)?":"Travel Enhancements", 
                         "What are your biggest concern(s)/fear(s) when travelling with luggage?":"Biggest travel Concerns & Fears", 
                         "How much would you be willing to pay for such a solution?":"Price Sensitivity for a Add-on Digital Solution"}, inplace = True)
NED_Df
# Out:
#      Age    Nationality   Current Residence     Occupation  \
# 0     21       Belgian     Dublin, Ireland        Student
# 1     22         german     Dublin, Ireland       Student
# 2     25  German, Swiss             Ireland        Student
# 3     22         German     Dublin, Ireland        Student
# 4     61         German  Kirchentellinsfurt  Civilengineer
# ..   ...            ...                 ...            ...
# 229   51         German     Valencia, Spain          None
# 230   23        German    Tübingen Germany        Student
# 231   22         German             Germany        Student
# 232   22          Swiss  Basel, Switzerland        Student
# 233   23      Sri Lanka   Olten Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                                      Bulky Luggage  \
# 0    No, I don’t use bulky luggage when traveling
# 1                                              NaN
# 2                                               No
# 3                                              NaN
# 4                                               No
# ..                                             ...
# 229                                            NaN
# 230                                            NaN
# 231                                            NaN
# 232                                            NaN
# 233                                        Clothes
#
#     Luggage Buying Plans (next year) Plan-to-buy Luggage Repacking Luggage  \
# 0                                 No                   /               Yes
# 1                                 No                 NaN               Yes
# 2                                 No                 NaN               Yes
# 3                                 No                 NaN               Yes
# 4                                 No                 NaN                No
# ..                               ...                 ...               ...
# 229                               No                 NaN               Yes
# 230                               No                 NaN               Yes
# 231                               No                 NaN               Yes
# 232                               No                 NaN               Yes
# 233                               No                 NaN               Yes
#
#     Forgotten luggage Misplaced Luggage by Airlines Smart Luggage Owner  \
# 0                 Yes                            No                  No
# 1                 Yes                           Yes                  No
# 2                 Yes                           Yes                  No
# 3                  No                            No                  No
# 4                  No                           Yes                  No
# ..                ...                           ...                 ...
# 229                No                           Yes                  No
# 230               Yes                           Yes                 Yes
# 231                No                           Yes                  No
# 232                No                           Yes                  No
# 233                No                            No                  No
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution
# 0                                             31-45
# 1                                             61-75
# 2                                             46-60
# 3                                             46-60
# 4                                             31-45
# ..                                              ...
# 229                 I would not buy such a solution
# 230                                         31-45 €
# 231                                         16-30 €
# 232                                        76-100 €
# 233                                         31-45 €
#
# [234 rows x 19 columns]

# %%
NED_Df = NED_Df[NED_Df['Age'] >= 18]
NED_Df
# Out:
#      Age    Nationality   Current Residence     Occupation  \
# 0     21       Belgian     Dublin, Ireland        Student
# 1     22         german     Dublin, Ireland       Student
# 2     25  German, Swiss             Ireland        Student
# 3     22         German     Dublin, Ireland        Student
# 4     61         German  Kirchentellinsfurt  Civilengineer
# ..   ...            ...                 ...            ...
# 229   51         German     Valencia, Spain          None
# 230   23        German    Tübingen Germany        Student
# 231   22         German             Germany        Student
# 232   22          Swiss  Basel, Switzerland        Student
# 233   23      Sri Lanka   Olten Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                                      Bulky Luggage  \
# 0    No, I don’t use bulky luggage when traveling
# 1                                              NaN
# 2                                               No
# 3                                              NaN
# 4                                               No
# ..                                             ...
# 229                                            NaN
# 230                                            NaN
# 231                                            NaN
# 232                                            NaN
# 233                                        Clothes
#
#     Luggage Buying Plans (next year) Plan-to-buy Luggage Repacking Luggage  \
# 0                                 No                   /               Yes
# 1                                 No                 NaN               Yes
# 2                                 No                 NaN               Yes
# 3                                 No                 NaN               Yes
# 4                                 No                 NaN                No
# ..                               ...                 ...               ...
# 229                               No                 NaN               Yes
# 230                               No                 NaN               Yes
# 231                               No                 NaN               Yes
# 232                               No                 NaN               Yes
# 233                               No                 NaN               Yes
#
#     Forgotten luggage Misplaced Luggage by Airlines Smart Luggage Owner  \
# 0                 Yes                            No                  No
# 1                 Yes                           Yes                  No
# 2                 Yes                           Yes                  No
# 3                  No                            No                  No
# 4                  No                           Yes                  No
# ..                ...                           ...                 ...
# 229                No                           Yes                  No
# 230               Yes                           Yes                 Yes
# 231                No                           Yes                  No
# 232                No                           Yes                  No
# 233                No                            No                  No
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution
# 0                                             31-45
# 1                                             61-75
# 2                                             46-60
# 3                                             46-60
# 4                                             31-45
# ..                                              ...
# 229                 I would not buy such a solution
# 230                                         31-45 €
# 231                                         16-30 €
# 232                                        76-100 €
# 233                                         31-45 €
#
# [231 rows x 19 columns]

# %%
NED_Df["Nationality"].unique()
# Out:
# array(['Belgian ', 'german', 'German, Swiss', 'German', 'GERMAN',
#        'belgian ', 'italian ', 'Swiss Italian', 'Belgian', 'French',
#        'Italian ', 'Italian', 'Various', 'German ', 'France', 'Austrian',
#        'Gemany', 'Turkish', 'Swiss', 'Germany', 'German and New Zealand ',
#        'German and irish', 'German / Irish', 'Germany ', 'Polish',
#        'German, French', 'Germany / UK / Malta ', 'german, swiss',
#        'germqn', 'German and British', 'Portuguese', 'greek',
#        'German, Bulgarian', 'German-brazilian', 'German / Italian',
#        'Deutsch ', 'German+ USA', 'Ferman', 'Swiss ', 'German, British',
#        'belgian french', 'French ', 'german ', 'German and Swiss',
#        'Austrian ', 'Mexican', 'USA (former Austria)', 'Tanzanian',
#        'Slowenian ', 'German, American ', 'Finnish', 'Austria, Germany',
#        'Austria', 'Singapore', 'German, Australian', 'Deutsch',
#        'Austria ', 'Sri Lanka'], dtype=object)

# %%
NED_Df["Nationality"] = NED_Df["Nationality"].str.capitalize()
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\681332796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"] = NED_Df["Nationality"].str.capitalize()
#      Age    Nationality   Current Residence     Occupation  \
# 0     21       Belgian     Dublin, Ireland        Student
# 1     22         German     Dublin, Ireland       Student
# 2     25  German, swiss             Ireland        Student
# 3     22         German     Dublin, Ireland        Student
# 4     61         German  Kirchentellinsfurt  Civilengineer
# ..   ...            ...                 ...            ...
# 229   51         German     Valencia, Spain          None
# 230   23        German    Tübingen Germany        Student
# 231   22         German             Germany        Student
# 232   22          Swiss  Basel, Switzerland        Student
# 233   23      Sri lanka   Olten Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                                      Bulky Luggage  \
# 0    No, I don’t use bulky luggage when traveling
# 1                                              NaN
# 2                                               No
# 3                                              NaN
# 4                                               No
# ..                                             ...
# 229                                            NaN
# 230                                            NaN
# 231                                            NaN
# 232                                            NaN
# 233                                        Clothes
#
#     Luggage Buying Plans (next year) Plan-to-buy Luggage Repacking Luggage  \
# 0                                 No                   /               Yes
# 1                                 No                 NaN               Yes
# 2                                 No                 NaN               Yes
# 3                                 No                 NaN               Yes
# 4                                 No                 NaN                No
# ..                               ...                 ...               ...
# 229                               No                 NaN               Yes
# 230                               No                 NaN               Yes
# 231                               No                 NaN               Yes
# 232                               No                 NaN               Yes
# 233                               No                 NaN               Yes
#
#     Forgotten luggage Misplaced Luggage by Airlines Smart Luggage Owner  \
# 0                 Yes                            No                  No
# 1                 Yes                           Yes                  No
# 2                 Yes                           Yes                  No
# 3                  No                            No                  No
# 4                  No                           Yes                  No
# ..                ...                           ...                 ...
# 229                No                           Yes                  No
# 230               Yes                           Yes                 Yes
# 231                No                           Yes                  No
# 232                No                           Yes                  No
# 233                No                            No                  No
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution
# 0                                             31-45
# 1                                             61-75
# 2                                             46-60
# 3                                             46-60
# 4                                             31-45
# ..                                              ...
# 229                 I would not buy such a solution
# 230                                         31-45 €
# 231                                         16-30 €
# 232                                        76-100 €
# 233                                         31-45 €
#
# [231 rows x 19 columns]

# %%
NED_Df["Nationality"].unique()
# Out:
# array(['Belgian ', 'German', 'German, swiss', 'Italian ', 'Swiss italian',
#        'Belgian', 'French', 'Italian', 'Various', 'German ', 'France',
#        'Austrian', 'Gemany', 'Turkish', 'Swiss', 'Germany',
#        'German and new zealand ', 'German and irish', 'German / irish',
#        'Germany ', 'Polish', 'German, french', 'Germany / uk / malta ',
#        'Germqn', 'German and british', 'Portuguese', 'Greek',
#        'German, bulgarian', 'German-brazilian', 'German / italian',
#        'Deutsch ', 'German+ usa', 'Ferman', 'Swiss ', 'German, british',
#        'Belgian french', 'French ', 'German and swiss', 'Austrian ',
#        'Mexican', 'Usa (former austria)', 'Tanzanian', 'Slowenian ',
#        'German, american ', 'Finnish', 'Austria, germany', 'Austria',
#        'Singapore', 'German, australian', 'Deutsch', 'Austria ',
#        'Sri lanka'], dtype=object)

# %%
NED_Df["Nationality"].replace("Germany", "German", inplace = True)
NED_Df["Nationality"].replace("Deutsch", "German", inplace = True)
NED_Df["Nationality"].replace("France", "French", inplace = True)
NED_Df["Nationality"].replace("Germqn", "German", inplace = True)
NED_Df["Nationality"].replace("Germany ", "German", inplace = True)
NED_Df["Nationality"].replace("Deutsch ", "German", inplace = True)
NED_Df["Nationality"].replace('Gemany', "German", inplace = True)
NED_Df["Nationality"].replace("Ferman", "German", inplace = True)
NED_Df["Nationality"].replace("Austria ", "Austria", inplace = True)
NED_Df["Nationality"].replace("Swiss ", "Swiss", inplace = True)
NED_Df["Nationality"].replace("Usa (former austria) ", "American", inplace = True)
NED_Df["Nationality"].replace('Usa (former austria)', "American", inplace = True)
NED_Df["Nationality"].replace('Belgian ', "Belgian", inplace = True)
NED_Df["Nationality"].replace('German ', "German", inplace = True)
NED_Df["Nationality"].replace('French ', "French", inplace = True)
NED_Df["Nationality"].replace("German, swiss", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("Swiss italian", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("German and new zealand ", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("German and irish", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("German and british", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("German, bulgarian", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("German, french", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace("Italian ", "Italian", inplace = True)
NED_Df["Nationality"].replace("Austria", "Austrian", inplace = True)
NED_Df["Nationality"].replace("Various", "Dual citizenship", inplace = True)
NED_Df["Nationality"].replace('German, american ', "Dual citizenship", inplace = True)

NED_Df["Nationality"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Germany", "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Deutsch", "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("France", "French", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Germqn", "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Germany ", "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Deutsch ", "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace('Gemany', "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Ferman", "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Austria ", "Austria", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Swiss ", "Swiss", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Usa (former austria) ", "American", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace('Usa (former austria)', "American", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace('Belgian ', "Belgian", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace('German ', "German", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace('French ', "French", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("German, swiss", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Swiss italian", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("German and new zealand ", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("German and irish", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("German and british", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("German, bulgarian", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("German, french", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Italian ", "Italian", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Austria", "Austrian", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace("Various", "Dual citizenship", inplace = True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3286635285.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace('German, american ', "Dual citizenship", inplace = True)
# array(['Belgian', 'German', 'Dual citizenship', 'Italian', 'French',
#        'Austrian', 'Turkish', 'Swiss', 'German / irish', 'Polish',
#        'Germany / uk / malta ', 'Portuguese', 'Greek', 'German-brazilian',
#        'German / italian', 'German+ usa', 'German, british',
#        'Belgian french', 'German and swiss', 'Austrian ', 'Mexican',
#        'American', 'Tanzanian', 'Slowenian ', 'Finnish',
#        'Austria, germany', 'Singapore', 'German, australian', 'Sri lanka'],
#       dtype=object)

# %%
values_to_replace = ["German / irish", "Germany / uk / malta ", "German-brazilian", "German / italian", "German+ usa", "German and french", "German, british", "Belgian french", "German and swiss", "German, american", "German, australian", "Austria, germany"]  
NED_Df["Nationality"].replace(values_to_replace, "Dual citizenship", inplace=True)
NED_Df["Nationality"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1892312498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Nationality"].replace(values_to_replace, "Dual citizenship", inplace=True)
# array(['Belgian', 'German', 'Dual citizenship', 'Italian', 'French',
#        'Austrian', 'Turkish', 'Swiss', 'Polish', 'Portuguese', 'Greek',
#        'Austrian ', 'Mexican', 'American', 'Tanzanian', 'Slowenian ',
#        'Finnish', 'Singapore', 'Sri lanka'], dtype=object)

# %%
nationality_counts = NED_Df["Nationality"].value_counts()

plt.pie(nationality_counts, labels=nationality_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Nationalities')
plt.show()

# %%
nationality_counts
# Out:
# German              173
# Dual citizenship     21
# Belgian               6
# French                6
# Austrian              5
# Italian               4
# Swiss                 4
# American              1
# Singapore             1
# Finnish               1
# Slowenian             1
# Tanzanian             1
# Portuguese            1
# Mexican               1
# Austrian              1
# Greek                 1
# Polish                1
# Turkish               1
# Sri lanka             1
# Name: Nationality, dtype: int64

# %%
conditions = [
    (NED_Df["Age"] <= 24),
    (NED_Df["Age"] >= 25) & (NED_Df["Age"] <= 33),
    (NED_Df["Age"] >= 34) & (NED_Df["Age"] <= 42),
    (NED_Df["Age"] >= 43) & (NED_Df["Age"] <= 51),
    (NED_Df["Age"] >= 52)
]

values = ["16-24", "25-33", "34-42", "43-51", ">52"]

NED_Df["Age Range"] = np.select(conditions, values, default="Unknown")
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1823515048.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Age Range"] = np.select(conditions, values, default="Unknown")
#      Age       Nationality   Current Residence     Occupation  \
# 0     21           Belgian    Dublin, Ireland        Student
# 1     22            German     Dublin, Ireland       Student
# 2     25  Dual citizenship             Ireland        Student
# 3     22            German     Dublin, Ireland        Student
# 4     61            German  Kirchentellinsfurt  Civilengineer
# ..   ...               ...                 ...            ...
# 229   51            German     Valencia, Spain          None
# 230   23            German   Tübingen Germany        Student
# 231   22            German             Germany        Student
# 232   22             Swiss  Basel, Switzerland        Student
# 233   23         Sri lanka   Olten Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                                      Bulky Luggage  \
# 0    No, I don’t use bulky luggage when traveling
# 1                                              NaN
# 2                                               No
# 3                                              NaN
# 4                                               No
# ..                                             ...
# 229                                            NaN
# 230                                            NaN
# 231                                            NaN
# 232                                            NaN
# 233                                        Clothes
#
#     Luggage Buying Plans (next year) Plan-to-buy Luggage Repacking Luggage  \
# 0                                 No                   /               Yes
# 1                                 No                 NaN               Yes
# 2                                 No                 NaN               Yes
# 3                                 No                 NaN               Yes
# 4                                 No                 NaN                No
# ..                               ...                 ...               ...
# 229                               No                 NaN               Yes
# 230                               No                 NaN               Yes
# 231                               No                 NaN               Yes
# 232                               No                 NaN               Yes
# 233                               No                 NaN               Yes
#
#     Forgotten luggage Misplaced Luggage by Airlines Smart Luggage Owner  \
# 0                 Yes                            No                  No
# 1                 Yes                           Yes                  No
# 2                 Yes                           Yes                  No
# 3                  No                            No                  No
# 4                  No                           Yes                  No
# ..                ...                           ...                 ...
# 229                No                           Yes                  No
# 230               Yes                           Yes                 Yes
# 231                No                           Yes                  No
# 232                No                           Yes                  No
# 233                No                            No                  No
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range
# 0                                             31-45     16-24
# 1                                             61-75     16-24
# 2                                             46-60     25-33
# 3                                             46-60     16-24
# 4                                             31-45       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
# [231 rows x 20 columns]

# %%
age_range_counts = NED_Df["Age Range"].value_counts()

plt.pie(age_range_counts, labels=age_range_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Age')
plt.show()

# %%
age_range_counts
# Out:
# 16-24    119
# >52       58
# 43-51     27
# 25-33     20
# 34-42      7
# Name: Age Range, dtype: int64

# %%
NED_Df["Current Residence"].unique()
# Out:
# array(['Dublin, Ireland ', 'Dublin, Ireland', 'Ireland',
#        'Kirchentellinsfurt', 'Weinstadt, Germany ', 'Lancaster, UK',
#        'Tübingen, Germany', 'Kirchentellinsfurt, Germany',
#        'BERLIN/GERMANY', 'bruxelles belgium',
#        'Maastricht, The Netherlands', 'Laaber - Germany', 'Belgium',
#        'Marseille france', 'Dubai / UAE', 'Rwanda', 'Kigali rwanda',
#        'Dubai, UAE', 'Esslingen, germany ', 'Lyon', 'Germany ',
#        'Bucharest', 'Frankfurt Germany ', 'Saudi Arabia',
#        'Kusatsu, Japan', 'Houston, Texas (USA)', 'Omaruru Namibia',
#        'Mainz', 'Kaarst germany', 'Santarém portugal ', 'Germany',
#        'hamburg/germany', 'Fargo, ND, USA', 'Hamburg Germany ',
#        'Haarlem/ Netherlands ', 'Leeds, UK ', 'Hannover, Germany',
#        'Auckland, New Zealand', 'Stuttgart/Germany', 'Galway, Ireland ',
#        'Utrecht, Netherlands', 'Günstadt Germany ', 'Stuttgart, Germany ',
#        'Stuttgart Germany', 'dublin ireland', 'Karlsruhe, Germany',
#        'Breda, Netherlands ', 'Ireland ', 'Frankfurt Germany',
#        'London, UK', 'Cambridge, UK', 'Huningue France', 'city',
#        'Cracow Poland ', 'Hong Kong, P. R. China', 'Stuttgart, Germany',
#        'London (GB)', 'Trier, Germany', 'Berlin / Germany',
#        'Germany, Bonn', 'Netherlands', 'Dublin', 'Augsburg, Germany',
#        'Marburg, Germany ', 'Austria', 'Mannheim, Germany', 'Italy',
#        'Frankfurt, Germany', 'Freiburg, Germany', 'Kassel, Germany',
#        '02799 Waltersdorf, Germany', 'Reutlingen, Germany',
#        'Jena, Germany ', 'Konstanz, Germany', 'Groningen ',
#        'Munich, Germany ', 'Liège, Belgium', 'Vancouver, Canada',
#        'Fladungen, Germany', 'Mainz, Germany', 'Loughborough, UK',
#        'Czech republic', 'Berlin, Germany', 'Suzhou, China',
#        'Kirchentellinsfurt, Germany ', 'Switzerland', 'uk',
#        'United Kingdom, Cambridgeshire', 'Country', 'Darmstadt, Germany',
#        'Dubai, United Arab Emirates', 'Madrid, Spain', 'Munich Germany ',
#        'stuttgart ,germany ', 'Bielefeld, Germany', 'Greece',
#        'Switzerland ', 'Granger USA', 'Leipzig, Germany',
#        'Munich, Germany', 'Lisbon, Portugal', 'Elon, US', 'Tokyo, Japan',
#        'UK', 'Hong Kong,  China ', 'Toulouse ', 'England ',
#        'Hanoi, Vietnam ', 'Dublin ', 'Heidelberg, Germany ',
#        'Heidelberg, germany ', 'Raleigh, United States',
#        'Deutschland, Hessen, Königstein im Taunus ', 'Dubai VAE',
#        'Canada', 'Glasgow, UK', 'Munich', 'Dresden, Germany ',
#        'Cologne, Germany ', 'Doha, Qatar',
#        'Pfaffenhofen an der Ilm, Germany', 'Montreal, Canada',
#        'Toronto, Canada', 'weinstadt, Germany', 'Toulouse, France',
#        'Dubai', 'Egypt ', 'Guildford, UK', 'Cologne', 'Dornbirn austria',
#        'Erlangen, Germany', 'Dublin Ireland ', 'Regensburg, Germany ',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Houston, United States', 'Elsterheide, Germany', 'Frankfurt',
#        'Beach Lake, USA', 'Jakarta, Indonesia', 'Usa', 'Utah, USA ',
#        'Beijing, China', 'Tanzania ', 'Basel, Switzerland ',
#        'Monroe, NY, USA', 'Singapore', 'Berlin, GERMANY ',
#        'Helsinki, Finland', 'Washington D.C., USA', 'Amman / Jordan',
#        'Sydney', 'Dresden in Deutschland ', 'Munich ', 'Amman, jordan',
#        'Uznach Switzerland ', 'Sierra leone', 'Maastricht, Netherlands',
#        'Valencia, Spain', 'Tübingen Germany ', 'Basel, Switzerland',
#        'Olten Switzerland'], dtype=object)

# %%
values_to_replace_IRE = ["Dublin, Ireland ", "Dublin, Ireland", "dublin ireland", "Galway, Ireland ", "Ireland ", "Dublin Ireland ", "Dublin", "Dublin "]  
NED_Df["Current Residence"].replace(values_to_replace_IRE, "Ireland", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2225833790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_IRE, "Ireland", inplace=True)
# array(['Ireland', 'Kirchentellinsfurt', 'Weinstadt, Germany ',
#        'Lancaster, UK', 'Tübingen, Germany',
#        'Kirchentellinsfurt, Germany', 'BERLIN/GERMANY',
#        'bruxelles belgium', 'Maastricht, The Netherlands',
#        'Laaber - Germany', 'Belgium', 'Marseille france', 'Dubai / UAE',
#        'Rwanda', 'Kigali rwanda', 'Dubai, UAE', 'Esslingen, germany ',
#        'Lyon', 'Germany ', 'Bucharest', 'Frankfurt Germany ',
#        'Saudi Arabia', 'Kusatsu, Japan', 'Houston, Texas (USA)',
#        'Omaruru Namibia', 'Mainz', 'Kaarst germany', 'Santarém portugal ',
#        'Germany', 'hamburg/germany', 'Fargo, ND, USA', 'Hamburg Germany ',
#        'Haarlem/ Netherlands ', 'Leeds, UK ', 'Hannover, Germany',
#        'Auckland, New Zealand', 'Stuttgart/Germany',
#        'Utrecht, Netherlands', 'Günstadt Germany ', 'Stuttgart, Germany ',
#        'Stuttgart Germany', 'Karlsruhe, Germany', 'Breda, Netherlands ',
#        'Frankfurt Germany', 'London, UK', 'Cambridge, UK',
#        'Huningue France', 'city', 'Cracow Poland ',
#        'Hong Kong, P. R. China', 'Stuttgart, Germany', 'London (GB)',
#        'Trier, Germany', 'Berlin / Germany', 'Germany, Bonn',
#        'Netherlands', 'Augsburg, Germany', 'Marburg, Germany ', 'Austria',
#        'Mannheim, Germany', 'Italy', 'Frankfurt, Germany',
#        'Freiburg, Germany', 'Kassel, Germany',
#        '02799 Waltersdorf, Germany', 'Reutlingen, Germany',
#        'Jena, Germany ', 'Konstanz, Germany', 'Groningen ',
#        'Munich, Germany ', 'Liège, Belgium', 'Vancouver, Canada',
#        'Fladungen, Germany', 'Mainz, Germany', 'Loughborough, UK',
#        'Czech republic', 'Berlin, Germany', 'Suzhou, China',
#        'Kirchentellinsfurt, Germany ', 'Switzerland', 'uk',
#        'United Kingdom, Cambridgeshire', 'Country', 'Darmstadt, Germany',
#        'Dubai, United Arab Emirates', 'Madrid, Spain', 'Munich Germany ',
#        'stuttgart ,germany ', 'Bielefeld, Germany', 'Greece',
#        'Switzerland ', 'Granger USA', 'Leipzig, Germany',
#        'Munich, Germany', 'Lisbon, Portugal', 'Elon, US', 'Tokyo, Japan',
#        'UK', 'Hong Kong,  China ', 'Toulouse ', 'England ',
#        'Hanoi, Vietnam ', 'Heidelberg, Germany ', 'Heidelberg, germany ',
#        'Raleigh, United States',
#        'Deutschland, Hessen, Königstein im Taunus ', 'Dubai VAE',
#        'Canada', 'Glasgow, UK', 'Munich', 'Dresden, Germany ',
#        'Cologne, Germany ', 'Doha, Qatar',
#        'Pfaffenhofen an der Ilm, Germany', 'Montreal, Canada',
#        'Toronto, Canada', 'weinstadt, Germany', 'Toulouse, France',
#        'Dubai', 'Egypt ', 'Guildford, UK', 'Cologne', 'Dornbirn austria',
#        'Erlangen, Germany', 'Regensburg, Germany ',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Houston, United States', 'Elsterheide, Germany', 'Frankfurt',
#        'Beach Lake, USA', 'Jakarta, Indonesia', 'Usa', 'Utah, USA ',
#        'Beijing, China', 'Tanzania ', 'Basel, Switzerland ',
#        'Monroe, NY, USA', 'Singapore', 'Berlin, GERMANY ',
#        'Helsinki, Finland', 'Washington D.C., USA', 'Amman / Jordan',
#        'Sydney', 'Dresden in Deutschland ', 'Munich ', 'Amman, jordan',
#        'Uznach Switzerland ', 'Sierra leone', 'Maastricht, Netherlands',
#        'Valencia, Spain', 'Tübingen Germany ', 'Basel, Switzerland',
#        'Olten Switzerland'], dtype=object)

# %%
values_to_replace_DE = ["Kirchentellinsfurt", 'Tübingen Germany ', "Weinstadt, Germany ", "Tübingen, Germany", "Kirchentellinsfurt, Germany", "BERLIN/GERMANY", "Laaber - Germany", "Esslingen, germany", "Germany ", "Frankfurt Germany ", "Kaarst germany", "Mainz", "hamburg/germany", "Hamburg Germany ", "Hannover, Germany", "Stuttgart/Germany", "Günstadt Germany ", "Stuttgart, Germany ", "Stuttgart Germany", "Karlsruhe, Germany", "Frankfurt Germany", "Stuttgart, Germany", "Trier, Germany", "Berlin / Germany", "Germany, Bonn", "Augsburg, Germany", "Marburg, Germany ", "Mannheim, Germany", 'Frankfurt, Germany', 'Freiburg, Germany', 'Kassel, Germany',
       '02799 Waltersdorf, Germany', 'Reutlingen, Germany', "Esslingen, germany ",
       'Jena, Germany ', 'Konstanz, Germany', "Munich, Germany ", "Fladungen, Germany", "Mainz, Germany", "Berlin, Germany","Kirchentellinsfurt, Germany ", "Darmstadt, Germany", "Munich Germany ", "stuttgart ,germany ", "Bielefeld, Germany", "Leipzig, Germany", "Munich, Germany", "Heidelberg, Germany ", "Heidelberg, germany ", "Deutschland, Hessen, Königstein im Taunus ", "Munich", "Dresden, Germany ", "Cologne, Germany ", "Pfaffenhofen an der Ilm, Germany", "weinstadt, Germany", "Germany, Schleswig-Holstein, 25436 Tornesch", "Frankfurt am Main, Germany", "Cologne", "Erlangen, Germany", "Regensburg, Germany ", "Elsterheide, Germany", "Frankfurt", "Berlin, GERMANY ", "Dresden in Deutschland ", "Munich "]  
NED_Df["Current Residence"].replace(values_to_replace_DE, "Germany", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\4062446003.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_DE, "Germany", inplace=True)
# array(['Ireland', 'Germany', 'Lancaster, UK', 'bruxelles belgium',
#        'Maastricht, The Netherlands', 'Belgium', 'Marseille france',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE', 'Lyon',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan',
#        'Houston, Texas (USA)', 'Omaruru Namibia', 'Santarém portugal ',
#        'Fargo, ND, USA', 'Haarlem/ Netherlands ', 'Leeds, UK ',
#        'Auckland, New Zealand', 'Utrecht, Netherlands',
#        'Breda, Netherlands ', 'London, UK', 'Cambridge, UK',
#        'Huningue France', 'city', 'Cracow Poland ',
#        'Hong Kong, P. R. China', 'London (GB)', 'Netherlands', 'Austria',
#        'Italy', 'Groningen ', 'Liège, Belgium', 'Vancouver, Canada',
#        'Loughborough, UK', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'uk', 'United Kingdom, Cambridgeshire', 'Country',
#        'Dubai, United Arab Emirates', 'Madrid, Spain', 'Greece',
#        'Switzerland ', 'Granger USA', 'Lisbon, Portugal', 'Elon, US',
#        'Tokyo, Japan', 'UK', 'Hong Kong,  China ', 'Toulouse ',
#        'England ', 'Hanoi, Vietnam ', 'Raleigh, United States',
#        'Dubai VAE', 'Canada', 'Glasgow, UK', 'Doha, Qatar',
#        'Montreal, Canada', 'Toronto, Canada', 'Toulouse, France', 'Dubai',
#        'Egypt ', 'Guildford, UK', 'Dornbirn austria',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Houston, United States', 'Beach Lake, USA', 'Jakarta, Indonesia',
#        'Usa', 'Utah, USA ', 'Beijing, China', 'Tanzania ',
#        'Basel, Switzerland ', 'Monroe, NY, USA', 'Singapore',
#        'Helsinki, Finland', 'Washington D.C., USA', 'Amman / Jordan',
#        'Sydney', 'Amman, jordan', 'Uznach Switzerland ', 'Sierra leone',
#        'Maastricht, Netherlands', 'Valencia, Spain', 'Basel, Switzerland',
#        'Olten Switzerland'], dtype=object)

# %%
values_to_replace_UK = ["Lancaster, UK", "Leeds, UK ", "London, UK", "Cambridge, UK", "London (GB)", "Loughborough, UK", "United Kingdom, Cambridgeshire", "England ", "Glasgow, UK", "Guildford, UK", "uk"]  
NED_Df["Current Residence"].replace(values_to_replace_UK, "UK", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2165322065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_UK, "UK", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'bruxelles belgium',
#        'Maastricht, The Netherlands', 'Belgium', 'Marseille france',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE', 'Lyon',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan',
#        'Houston, Texas (USA)', 'Omaruru Namibia', 'Santarém portugal ',
#        'Fargo, ND, USA', 'Haarlem/ Netherlands ', 'Auckland, New Zealand',
#        'Utrecht, Netherlands', 'Breda, Netherlands ', 'Huningue France',
#        'city', 'Cracow Poland ', 'Hong Kong, P. R. China', 'Netherlands',
#        'Austria', 'Italy', 'Groningen ', 'Liège, Belgium',
#        'Vancouver, Canada', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'Country', 'Dubai, United Arab Emirates',
#        'Madrid, Spain', 'Greece', 'Switzerland ', 'Granger USA',
#        'Lisbon, Portugal', 'Elon, US', 'Tokyo, Japan',
#        'Hong Kong,  China ', 'Toulouse ', 'Hanoi, Vietnam ',
#        'Raleigh, United States', 'Dubai VAE', 'Canada', 'Doha, Qatar',
#        'Montreal, Canada', 'Toronto, Canada', 'Toulouse, France', 'Dubai',
#        'Egypt ', 'Dornbirn austria', 'Zürich, Switzerland ',
#        'St. Gallen, Switzerland', 'Lahore ', 'Houston, United States',
#        'Beach Lake, USA', 'Jakarta, Indonesia', 'Usa', 'Utah, USA ',
#        'Beijing, China', 'Tanzania ', 'Basel, Switzerland ',
#        'Monroe, NY, USA', 'Singapore', 'Helsinki, Finland',
#        'Washington D.C., USA', 'Amman / Jordan', 'Sydney',
#        'Amman, jordan', 'Uznach Switzerland ', 'Sierra leone',
#        'Maastricht, Netherlands', 'Valencia, Spain', 'Basel, Switzerland',
#        'Olten Switzerland'], dtype=object)

# %%
values_to_replace_Belgium = ["bruxelles belgium", "waterloo belgium ", "Liège, Belgium"]  
NED_Df["Current Residence"].replace(values_to_replace_Belgium, "Belgium", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3158150278.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Belgium, "Belgium", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium',
#        'Maastricht, The Netherlands', 'Marseille france', 'Dubai / UAE',
#        'Rwanda', 'Kigali rwanda', 'Dubai, UAE', 'Lyon', 'Bucharest',
#        'Saudi Arabia', 'Kusatsu, Japan', 'Houston, Texas (USA)',
#        'Omaruru Namibia', 'Santarém portugal ', 'Fargo, ND, USA',
#        'Haarlem/ Netherlands ', 'Auckland, New Zealand',
#        'Utrecht, Netherlands', 'Breda, Netherlands ', 'Huningue France',
#        'city', 'Cracow Poland ', 'Hong Kong, P. R. China', 'Netherlands',
#        'Austria', 'Italy', 'Groningen ', 'Vancouver, Canada',
#        'Czech republic', 'Suzhou, China', 'Switzerland', 'Country',
#        'Dubai, United Arab Emirates', 'Madrid, Spain', 'Greece',
#        'Switzerland ', 'Granger USA', 'Lisbon, Portugal', 'Elon, US',
#        'Tokyo, Japan', 'Hong Kong,  China ', 'Toulouse ',
#        'Hanoi, Vietnam ', 'Raleigh, United States', 'Dubai VAE', 'Canada',
#        'Doha, Qatar', 'Montreal, Canada', 'Toronto, Canada',
#        'Toulouse, France', 'Dubai', 'Egypt ', 'Dornbirn austria',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Houston, United States', 'Beach Lake, USA', 'Jakarta, Indonesia',
#        'Usa', 'Utah, USA ', 'Beijing, China', 'Tanzania ',
#        'Basel, Switzerland ', 'Monroe, NY, USA', 'Singapore',
#        'Helsinki, Finland', 'Washington D.C., USA', 'Amman / Jordan',
#        'Sydney', 'Amman, jordan', 'Uznach Switzerland ', 'Sierra leone',
#        'Maastricht, Netherlands', 'Valencia, Spain', 'Basel, Switzerland',
#        'Olten Switzerland'], dtype=object)

# %%
values_to_replace_Netherlands = ["Maastricht, The Netherlands", "Haarlem/ Netherlands ", "Utrecht, Netherlands", "Breda, Netherlands ", "Groningen ", "Maastricht, Netherlands"]  
NED_Df["Current Residence"].replace(values_to_replace_Netherlands, "Netherlands", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\315359193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Netherlands, "Netherlands", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands',
#        'Marseille france', 'Dubai / UAE', 'Rwanda', 'Kigali rwanda',
#        'Dubai, UAE', 'Lyon', 'Bucharest', 'Saudi Arabia',
#        'Kusatsu, Japan', 'Houston, Texas (USA)', 'Omaruru Namibia',
#        'Santarém portugal ', 'Fargo, ND, USA', 'Auckland, New Zealand',
#        'Huningue France', 'city', 'Cracow Poland ',
#        'Hong Kong, P. R. China', 'Austria', 'Italy', 'Vancouver, Canada',
#        'Czech republic', 'Suzhou, China', 'Switzerland', 'Country',
#        'Dubai, United Arab Emirates', 'Madrid, Spain', 'Greece',
#        'Switzerland ', 'Granger USA', 'Lisbon, Portugal', 'Elon, US',
#        'Tokyo, Japan', 'Hong Kong,  China ', 'Toulouse ',
#        'Hanoi, Vietnam ', 'Raleigh, United States', 'Dubai VAE', 'Canada',
#        'Doha, Qatar', 'Montreal, Canada', 'Toronto, Canada',
#        'Toulouse, France', 'Dubai', 'Egypt ', 'Dornbirn austria',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Houston, United States', 'Beach Lake, USA', 'Jakarta, Indonesia',
#        'Usa', 'Utah, USA ', 'Beijing, China', 'Tanzania ',
#        'Basel, Switzerland ', 'Monroe, NY, USA', 'Singapore',
#        'Helsinki, Finland', 'Washington D.C., USA', 'Amman / Jordan',
#        'Sydney', 'Amman, jordan', 'Uznach Switzerland ', 'Sierra leone',
#        'Valencia, Spain', 'Basel, Switzerland', 'Olten Switzerland'],
#       dtype=object)

# %%
values_to_replace_France = ["Marseille france", "Lyon", "Toulouse ", "Toulouse, France", "Huningue France"]  
NED_Df["Current Residence"].replace(values_to_replace_France, "France", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2872866495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_France, "France", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan',
#        'Houston, Texas (USA)', 'Omaruru Namibia', 'Santarém portugal ',
#        'Fargo, ND, USA', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'Hong Kong, P. R. China', 'Austria', 'Italy',
#        'Vancouver, Canada', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'Country', 'Dubai, United Arab Emirates',
#        'Madrid, Spain', 'Greece', 'Switzerland ', 'Granger USA',
#        'Lisbon, Portugal', 'Elon, US', 'Tokyo, Japan',
#        'Hong Kong,  China ', 'Hanoi, Vietnam ', 'Raleigh, United States',
#        'Dubai VAE', 'Canada', 'Doha, Qatar', 'Montreal, Canada',
#        'Toronto, Canada', 'Dubai', 'Egypt ', 'Dornbirn austria',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Houston, United States', 'Beach Lake, USA', 'Jakarta, Indonesia',
#        'Usa', 'Utah, USA ', 'Beijing, China', 'Tanzania ',
#        'Basel, Switzerland ', 'Monroe, NY, USA', 'Singapore',
#        'Helsinki, Finland', 'Washington D.C., USA', 'Amman / Jordan',
#        'Sydney', 'Amman, jordan', 'Uznach Switzerland ', 'Sierra leone',
#        'Valencia, Spain', 'Basel, Switzerland', 'Olten Switzerland'],
#       dtype=object)

# %%
values_to_replace_Spain = ["Madrid, Spain", "Valencia, Spain"]  
NED_Df["Current Residence"].replace(values_to_replace_Spain, "Spain", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2094780191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Spain, "Spain", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan',
#        'Houston, Texas (USA)', 'Omaruru Namibia', 'Santarém portugal ',
#        'Fargo, ND, USA', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'Hong Kong, P. R. China', 'Austria', 'Italy',
#        'Vancouver, Canada', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'Country', 'Dubai, United Arab Emirates', 'Spain',
#        'Greece', 'Switzerland ', 'Granger USA', 'Lisbon, Portugal',
#        'Elon, US', 'Tokyo, Japan', 'Hong Kong,  China ',
#        'Hanoi, Vietnam ', 'Raleigh, United States', 'Dubai VAE', 'Canada',
#        'Doha, Qatar', 'Montreal, Canada', 'Toronto, Canada', 'Dubai',
#        'Egypt ', 'Dornbirn austria', 'Zürich, Switzerland ',
#        'St. Gallen, Switzerland', 'Lahore ', 'Houston, United States',
#        'Beach Lake, USA', 'Jakarta, Indonesia', 'Usa', 'Utah, USA ',
#        'Beijing, China', 'Tanzania ', 'Basel, Switzerland ',
#        'Monroe, NY, USA', 'Singapore', 'Helsinki, Finland',
#        'Washington D.C., USA', 'Amman / Jordan', 'Sydney',
#        'Amman, jordan', 'Uznach Switzerland ', 'Sierra leone',
#        'Basel, Switzerland', 'Olten Switzerland'], dtype=object)

# %%
values_to_replace_USA = ["Houston, Texas (USA)", "Fargo, ND, USA", "Granger USA", "Elon, US", "Raleigh, United States", "Houston, United States", "Beach Lake, USA", "Usa", "Utah, USA ", "Monroe, NY, USA", "Washington D.C., USA"]  
NED_Df["Current Residence"].replace(values_to_replace_USA, "USA", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1316906307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_USA, "USA", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan', 'USA',
#        'Omaruru Namibia', 'Santarém portugal ', 'Auckland, New Zealand',
#        'city', 'Cracow Poland ', 'Hong Kong, P. R. China', 'Austria',
#        'Italy', 'Vancouver, Canada', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'Country', 'Dubai, United Arab Emirates', 'Spain',
#        'Greece', 'Switzerland ', 'Lisbon, Portugal', 'Tokyo, Japan',
#        'Hong Kong,  China ', 'Hanoi, Vietnam ', 'Dubai VAE', 'Canada',
#        'Doha, Qatar', 'Montreal, Canada', 'Toronto, Canada', 'Dubai',
#        'Egypt ', 'Dornbirn austria', 'Zürich, Switzerland ',
#        'St. Gallen, Switzerland', 'Lahore ', 'Jakarta, Indonesia',
#        'Beijing, China', 'Tanzania ', 'Basel, Switzerland ', 'Singapore',
#        'Helsinki, Finland', 'Amman / Jordan', 'Sydney', 'Amman, jordan',
#        'Uznach Switzerland ', 'Sierra leone', 'Basel, Switzerland',
#        'Olten Switzerland'], dtype=object)

# %%
values_to_replace_Canada = ["Vancouver, Canada", "Montreal, Canada", "Toronto, Canada"]  
NED_Df["Current Residence"].replace(values_to_replace_Canada, "Canada", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1714929447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Canada, "Canada", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan', 'USA',
#        'Omaruru Namibia', 'Santarém portugal ', 'Auckland, New Zealand',
#        'city', 'Cracow Poland ', 'Hong Kong, P. R. China', 'Austria',
#        'Italy', 'Canada', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'Country', 'Dubai, United Arab Emirates', 'Spain',
#        'Greece', 'Switzerland ', 'Lisbon, Portugal', 'Tokyo, Japan',
#        'Hong Kong,  China ', 'Hanoi, Vietnam ', 'Dubai VAE',
#        'Doha, Qatar', 'Dubai', 'Egypt ', 'Dornbirn austria',
#        'Zürich, Switzerland ', 'St. Gallen, Switzerland', 'Lahore ',
#        'Jakarta, Indonesia', 'Beijing, China', 'Tanzania ',
#        'Basel, Switzerland ', 'Singapore', 'Helsinki, Finland',
#        'Amman / Jordan', 'Sydney', 'Amman, jordan', 'Uznach Switzerland ',
#        'Sierra leone', 'Basel, Switzerland', 'Olten Switzerland'],
#       dtype=object)

# %%
values_to_replace_Switzerland = ["Switzerland ", "Zürich, Switzerland ", 'Olten Switzerland', 'Basel, Switzerland', "St. Gallen, Switzerland", "Basel, Switzerland ", "Uznach Switzerland "]  
NED_Df["Current Residence"].replace(values_to_replace_Switzerland, "Switzerland", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1836523029.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Switzerland, "Switzerland", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'Dubai / UAE', 'Rwanda', 'Kigali rwanda', 'Dubai, UAE',
#        'Bucharest', 'Saudi Arabia', 'Kusatsu, Japan', 'USA',
#        'Omaruru Namibia', 'Santarém portugal ', 'Auckland, New Zealand',
#        'city', 'Cracow Poland ', 'Hong Kong, P. R. China', 'Austria',
#        'Italy', 'Canada', 'Czech republic', 'Suzhou, China',
#        'Switzerland', 'Country', 'Dubai, United Arab Emirates', 'Spain',
#        'Greece', 'Lisbon, Portugal', 'Tokyo, Japan', 'Hong Kong,  China ',
#        'Hanoi, Vietnam ', 'Dubai VAE', 'Doha, Qatar', 'Dubai', 'Egypt ',
#        'Dornbirn austria', 'Lahore ', 'Jakarta, Indonesia',
#        'Beijing, China', 'Tanzania ', 'Singapore', 'Helsinki, Finland',
#        'Amman / Jordan', 'Sydney', 'Amman, jordan', 'Sierra leone'],
#       dtype=object)

# %%
values_to_replace_UAE = ["Dubai / UAE", "Dubai, UAE", "Dubai, United Arab Emirates", "Dubai", "Dubai VAE"]  
NED_Df["Current Residence"].replace(values_to_replace_UAE, "United Arab Emirates", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3779606966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_UAE, "United Arab Emirates", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Kusatsu, Japan', 'USA', 'Omaruru Namibia',
#        'Santarém portugal ', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'Hong Kong, P. R. China', 'Austria', 'Italy',
#        'Canada', 'Czech republic', 'Suzhou, China', 'Switzerland',
#        'Country', 'Spain', 'Greece', 'Lisbon, Portugal', 'Tokyo, Japan',
#        'Hong Kong,  China ', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Dornbirn austria', 'Lahore ', 'Jakarta, Indonesia',
#        'Beijing, China', 'Tanzania ', 'Singapore', 'Helsinki, Finland',
#        'Amman / Jordan', 'Sydney', 'Amman, jordan', 'Sierra leone'],
#       dtype=object)

# %%
values_to_replace_China = ["Hong Kong, P. R. China", "Suzhou, China", "Hong Kong,  China ", "Beijing, China"]  
NED_Df["Current Residence"].replace(values_to_replace_China, "China", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\726370338.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_China, "China", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Kusatsu, Japan', 'USA', 'Omaruru Namibia',
#        'Santarém portugal ', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Lisbon, Portugal', 'Tokyo, Japan', 'Hanoi, Vietnam ',
#        'Doha, Qatar', 'Egypt ', 'Dornbirn austria', 'Lahore ',
#        'Jakarta, Indonesia', 'Tanzania ', 'Singapore',
#        'Helsinki, Finland', 'Amman / Jordan', 'Sydney', 'Amman, jordan',
#        'Sierra leone'], dtype=object)

# %%
values_to_replace_Japan = ["Kusatsu, Japan", "Tokyo, Japan"]  
NED_Df["Current Residence"].replace(values_to_replace_Japan, "Japan", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\142948057.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Japan, "Japan", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Japan', 'USA', 'Omaruru Namibia',
#        'Santarém portugal ', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Lisbon, Portugal', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Dornbirn austria', 'Lahore ', 'Jakarta, Indonesia', 'Tanzania ',
#        'Singapore', 'Helsinki, Finland', 'Amman / Jordan', 'Sydney',
#        'Amman, jordan', 'Sierra leone'], dtype=object)

# %%
values_to_replace_Jordan = ["Amman / Jordan", "Amman, jordan"]  
NED_Df["Current Residence"].replace(values_to_replace_Jordan, "Jordan", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2800587927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Jordan, "Jordan", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Japan', 'USA', 'Omaruru Namibia',
#        'Santarém portugal ', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Lisbon, Portugal', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Dornbirn austria', 'Lahore ', 'Jakarta, Indonesia', 'Tanzania ',
#        'Singapore', 'Helsinki, Finland', 'Jordan', 'Sydney',
#        'Sierra leone'], dtype=object)

# %%
values_to_replace_Australia = ["Sydney"]  
NED_Df["Current Residence"].replace(values_to_replace_Australia, "Australia", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3197354940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Australia, "Australia", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Japan', 'USA', 'Omaruru Namibia',
#        'Santarém portugal ', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Lisbon, Portugal', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Dornbirn austria', 'Lahore ', 'Jakarta, Indonesia', 'Tanzania ',
#        'Singapore', 'Helsinki, Finland', 'Jordan', 'Australia',
#        'Sierra leone'], dtype=object)

# %%
values_to_replace_Austria = ["Dornbirn austria"]  
NED_Df["Current Residence"].replace(values_to_replace_Austria, "Austria", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3797244243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Austria, "Austria", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Japan', 'USA', 'Omaruru Namibia',
#        'Santarém portugal ', 'Auckland, New Zealand', 'city',
#        'Cracow Poland ', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Lisbon, Portugal', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Lahore ', 'Jakarta, Indonesia', 'Tanzania ', 'Singapore',
#        'Helsinki, Finland', 'Jordan', 'Australia', 'Sierra leone'],
#       dtype=object)

# %%
values_to_replace_Portugal = ["Santarém portugal ", "Lisbon, Portugal"]  
NED_Df["Current Residence"].replace(values_to_replace_Portugal, "Portugal", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\794200351.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Portugal, "Portugal", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Kigali rwanda', 'Bucharest',
#        'Saudi Arabia', 'Japan', 'USA', 'Omaruru Namibia', 'Portugal',
#        'Auckland, New Zealand', 'city', 'Cracow Poland ', 'China',
#        'Austria', 'Italy', 'Canada', 'Czech republic', 'Switzerland',
#        'Country', 'Spain', 'Greece', 'Hanoi, Vietnam ', 'Doha, Qatar',
#        'Egypt ', 'Lahore ', 'Jakarta, Indonesia', 'Tanzania ',
#        'Singapore', 'Helsinki, Finland', 'Jordan', 'Australia',
#        'Sierra leone'], dtype=object)

# %%
values_to_replace_Rwanda = ["Kigali rwanda"]  
NED_Df["Current Residence"].replace(values_to_replace_Rwanda, "Rwanda", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1542832164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Rwanda, "Rwanda", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Omaruru Namibia', 'Portugal',
#        'Auckland, New Zealand', 'city', 'Cracow Poland ', 'China',
#        'Austria', 'Italy', 'Canada', 'Czech republic', 'Switzerland',
#        'Country', 'Spain', 'Greece', 'Hanoi, Vietnam ', 'Doha, Qatar',
#        'Egypt ', 'Lahore ', 'Jakarta, Indonesia', 'Tanzania ',
#        'Singapore', 'Helsinki, Finland', 'Jordan', 'Australia',
#        'Sierra leone'], dtype=object)

# %%
values_to_replace_Finland = ["Helsinki, Finland"]  
NED_Df["Current Residence"].replace(values_to_replace_Finland, "Finland", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3674712149.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Finland, "Finland", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Omaruru Namibia', 'Portugal',
#        'Auckland, New Zealand', 'city', 'Cracow Poland ', 'China',
#        'Austria', 'Italy', 'Canada', 'Czech republic', 'Switzerland',
#        'Country', 'Spain', 'Greece', 'Hanoi, Vietnam ', 'Doha, Qatar',
#        'Egypt ', 'Lahore ', 'Jakarta, Indonesia', 'Tanzania ',
#        'Singapore', 'Finland', 'Jordan', 'Australia', 'Sierra leone'],
#       dtype=object)

# %%
values_to_replace_Poland = ["Cracow Poland "]  
NED_Df["Current Residence"].replace(values_to_replace_Poland, "Poland", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\443564043.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Poland, "Poland", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Omaruru Namibia', 'Portugal',
#        'Auckland, New Zealand', 'city', 'Poland', 'China', 'Austria',
#        'Italy', 'Canada', 'Czech republic', 'Switzerland', 'Country',
#        'Spain', 'Greece', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Lahore ', 'Jakarta, Indonesia', 'Tanzania ', 'Singapore',
#        'Finland', 'Jordan', 'Australia', 'Sierra leone'], dtype=object)

# %%
values_to_replace_Pakhistan = ["Lahore "]  
NED_Df["Current Residence"].replace(values_to_replace_Pakhistan, "Pakhistan", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2047634600.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Pakhistan, "Pakhistan", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Omaruru Namibia', 'Portugal',
#        'Auckland, New Zealand', 'city', 'Poland', 'China', 'Austria',
#        'Italy', 'Canada', 'Czech republic', 'Switzerland', 'Country',
#        'Spain', 'Greece', 'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ',
#        'Pakhistan', 'Jakarta, Indonesia', 'Tanzania ', 'Singapore',
#        'Finland', 'Jordan', 'Australia', 'Sierra leone'], dtype=object)

# %%
values_to_replace_Namibia = ["Omaruru Namibia"]  
NED_Df["Current Residence"].replace(values_to_replace_Namibia, "Namibia", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1633543387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Namibia, "Namibia", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Namibia', 'Portugal', 'Auckland, New Zealand',
#        'city', 'Poland', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ', 'Pakhistan',
#        'Jakarta, Indonesia', 'Tanzania ', 'Singapore', 'Finland',
#        'Jordan', 'Australia', 'Sierra leone'], dtype=object)

# %%
values_to_replace_Indonesia = ["Jakarta, Indonesia"]  
NED_Df["Current Residence"].replace(values_to_replace_Indonesia, "Indonesia", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3770517093.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Indonesia, "Indonesia", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Namibia', 'Portugal', 'Auckland, New Zealand',
#        'city', 'Poland', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Country', 'Spain', 'Greece',
#        'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ', 'Pakhistan',
#        'Indonesia', 'Tanzania ', 'Singapore', 'Finland', 'Jordan',
#        'Australia', 'Sierra leone'], dtype=object)

# %%
values_to_replace = ["Country", "city"]  
NED_Df["Current Residence"].replace(values_to_replace, "NaN", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1650624924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace, "NaN", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Namibia', 'Portugal', 'Auckland, New Zealand',
#        'NaN', 'Poland', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Spain', 'Greece',
#        'Hanoi, Vietnam ', 'Doha, Qatar', 'Egypt ', 'Pakhistan',
#        'Indonesia', 'Tanzania ', 'Singapore', 'Finland', 'Jordan',
#        'Australia', 'Sierra leone'], dtype=object)

# %%
values_to_replace_Qatar = ["Doha, Qatar"]  
NED_Df["Current Residence"].replace(values_to_replace_Qatar, "Qatar", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3506712164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Qatar, "Qatar", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Namibia', 'Portugal', 'Auckland, New Zealand',
#        'NaN', 'Poland', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Spain', 'Greece',
#        'Hanoi, Vietnam ', 'Qatar', 'Egypt ', 'Pakhistan', 'Indonesia',
#        'Tanzania ', 'Singapore', 'Finland', 'Jordan', 'Australia',
#        'Sierra leone'], dtype=object)

# %%
values_to_replace_Vietnam = ["Hanoi, Vietnam "]  
NED_Df["Current Residence"].replace(values_to_replace_Vietnam, "Vietnam", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2144242668.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Vietnam, "Vietnam", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Bucharest', 'Saudi Arabia',
#        'Japan', 'USA', 'Namibia', 'Portugal', 'Auckland, New Zealand',
#        'NaN', 'Poland', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Spain', 'Greece', 'Vietnam',
#        'Qatar', 'Egypt ', 'Pakhistan', 'Indonesia', 'Tanzania ',
#        'Singapore', 'Finland', 'Jordan', 'Australia', 'Sierra leone'],
#       dtype=object)

# %%
values_to_replace_Romania = ["Bucharest"]  
NED_Df["Current Residence"].replace(values_to_replace_Romania, "Romania", inplace=True)
NED_Df["Current Residence"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\711820507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Current Residence"].replace(values_to_replace_Romania, "Romania", inplace=True)
# array(['Ireland', 'Germany', 'UK', 'Belgium', 'Netherlands', 'France',
#        'United Arab Emirates', 'Rwanda', 'Romania', 'Saudi Arabia',
#        'Japan', 'USA', 'Namibia', 'Portugal', 'Auckland, New Zealand',
#        'NaN', 'Poland', 'China', 'Austria', 'Italy', 'Canada',
#        'Czech republic', 'Switzerland', 'Spain', 'Greece', 'Vietnam',
#        'Qatar', 'Egypt ', 'Pakhistan', 'Indonesia', 'Tanzania ',
#        'Singapore', 'Finland', 'Jordan', 'Australia', 'Sierra leone'],
#       dtype=object)

# %%
residence_counts = NED_Df["Current Residence"].value_counts()

plt.pie(residence_counts, labels=residence_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Residence')
plt.show()

# %%
residence_counts
# Out:
# Germany                  96
# Ireland                  32
# UK                       14
# USA                      11
# Switzerland               9
# Netherlands               7
# United Arab Emirates      6
# Belgium                   5
# France                    5
# Canada                    5
# China                     4
# Rwanda                    3
# Portugal                  3
# Italy                     3
# Singapore                 2
# Spain                     2
# Jordan                    2
# Austria                   2
# Japan                     2
# NaN                       2
# Poland                    1
# Pakhistan                 1
# Australia                 1
# Romania                   1
# Finland                   1
# Saudi Arabia              1
# Tanzania                  1
# Indonesia                 1
# Egypt                     1
# Qatar                     1
# Vietnam                   1
# Greece                    1
# Namibia                   1
# Czech republic            1
# Auckland, New Zealand     1
# Sierra leone              1
# Name: Current Residence, dtype: int64

# %%
NED_Df["Occupation"].unique()
# Out:
# array(['Student ', 'Student', 'Civilengineer', 'CEO',
#        'Publishing service provider', 'student ', 'Housewife',
#        'Nutritionist ', 'Medical sciences ',
#        'Driver/Cook/Cleaner/Entertainer/Therapist', 'Self employed',
#        'Self employed ', 'Business manager ', 'Manager', 'Social worker',
#        'Teacher', 'Sales director ', 'None', 'Managing Director ',
#        'Homemaker', 'Self-employed', 'Nurse', 'Office Manager ',
#        'Consultant', 'Retired', 'Market research consultant',
#        'Interim manager- self employed ', 'Software Consultant',
#        'advisor', 'Banker', 'Professor at University ',
#        'Backoffice Manager', 'Business owner (Coach)',
#        'Credit risk analyst ', 'Pharmacist ', 'Physiotherapist',
#        'Customer support ', 'Translator', 'psycholoog', 'retired',
#        'Student at a University ', 'working student', 'Intern', 'student',
#        'Real Estate Business', 'Goldsmith ', 'Student / Working Student',
#        'university student ', 'Student, but also working at DZ BANK',
#        'Employee', 'Photographer', 'Sales', nan, 'Consultant ', 'Stduent',
#        'Office Assistant', 'Basket ball', 'Graphic designer',
#        'Civil Engineering', 'Self-employed consultant',
#        'Assistent Productionmanager', 'PostDoc', 'Personal assistant',
#        'employed', 'Self ocvupied in tourism', 'Journalist', 'Home maker',
#        'Student Assistent', 'Music student ', 'Trainee PR',
#        'Education Consultant', 'Social and psychological counselor ',
#        'Diplomat (Angestellte geh. Dienst)', 'Architect ', 'Apartment  ',
#        'Physiotherapeutin ', 'Property Manager', 'Executive Assistant ',
#        'EMS-Personaltrainer and Human Ressource Manager ',
#        'Student & part-time flight attendant ', 'Teacher ', 'Executive ',
#        'Not working', 'Interior designer', 'Self occupied ', 'Midwife',
#        'Senior Vice President', 'Software-Engineer/Computer Scientist ',
#        'Business Development for Training Company', 'Travelagent',
#        'Head of Marketing & Communication ',
#        'Consultant in a Student Consultancy & Student', 'Labour lawyer',
#        'Direct Sales and Stay at home mom', 'school secretary',
#        'Management Assistant ', 'Tour operator', 'Test Manager',
#        'Web designer', 'Intern, Founder‘s Associate ', 'dual student',
#        'Student / Private Equity Working Student', 'Customer Success',
#        'Assistant', 'Shipping Operator', 'Senior Researcher',
#        'Architektur Student', 'Housewife ', 'Travel agent',
#        'Pharmacist at the UN', 'None '], dtype=object)

# %%
students = ['Music student ',"Students",'Student','student ','Stduent','gap year','Student at a University','university student ','Student, but also working at DZ BANK','working student','Student / Working Student','Student / Private Equity Working Student','dual student','Architektur Student','Consultant in a Student Consultancy & Student','Student & part-time flight attendant','School']
retired =['Retired', 'retired']
unknown = ['-', 'None', 'Not working', 'None ']
homemakers = ['Housewife','Homemaker','Home maker','Housewife ','Midwife','Direct Sales and Stay at home mom']
healthcare_professions = ['EMS-Personaltrainer and Human Ressource Manager','psycholoog','Nutritionist','Medical sciences','Nurse','Physiotherapeutin','Pharmacist','Physiotherapist','Pharmacist at the UN','Nutritionist','Medical sciences']
education_professions = ['Teacher','Professor at University','Student Assistent','Education Consultant']
creative_professions = ['Architect','Interior designer','Publishing service provider','Photographer','Graphic designer','Web designer','Real Estate Business','Goldsmith','Journalist','Music student','Web designer','Translator']
management_professionals = ['Sales director','Assistent Productionmanager','Sales','Office Assistant','Self occupied','school secretary','Self occupied ','Business Development for Training Company','Personal assistant','Office Manager','Business Development for Training Company','Assistant','Management Assistant ','Executive Assistant','EMS-Personaltrainer and Human Resource Manager ','Executive','CEO','Business manager','Manager','Self employed','Self employed','Self-employed','Interim manager- self employed','Backoffice Manager','Business owner (Coach)','Senior Vice President','Head of Marketing & Communication','Management Assistant','Test Manager','Managing Director','Customer support']
advisory = ['Social and psychological counselor','Self-employed consultant','Advisor','Consultant','Labour lawyer','Market research consultant','Software Consultant']
finance = ['Banker','Credit risk analyst']
research = ['Senior Researcher','PostDoc']
engineering_professionals = ['Civilengineer','Civil Engineering','Software-Engineer/Computer Scientist']
marketing_professions = ['Sales director ','Trainee PR','Customer Success']
social_professions = ['Social worker','Social and psychological counselor ']
hospitality_professions = ['Driver/Cook/Cleaner/Entertainer/Therapist','Self ocvupied in tourism','Tour operator','Travel agent','Shipping Operator','Travel agent ','Travelagent']
government_professions = ['Diplomat (Angestellte geh. Dienst)']
architecture_professions = ['Architect ','Apartment ','Property Manager']
miscellaneous = ['Intern','Basket ball','Intern, Founder‘s Associate'] 

conditions = [
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, students)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, retired)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, unknown)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, homemakers)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, healthcare_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, education_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, creative_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, management_professionals)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, advisory)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, finance)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, research)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, engineering_professionals)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, marketing_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, social_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, hospitality_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, government_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, architecture_professions)),
    NED_Df["Occupation"].str.strip().str.lower().isin(map(str.lower, miscellaneous))
]


choices = ["Students", 
           "Retired", 
           "Unknown", 
           "Homemakers",
           "Healthcare Professions",
           "Education Professions",
           "Creative and Design Professions",
           "Management Professions", 
           "Advisory and Consulting Professions", 
           "Finance and Banking", 
           "Researcher", 
           "Engineering Professions", 
           "Marketing Professions", 
           "Social Professions", 
           "Hospitality Professions",
           "Governmental Professions",
           "Architecture Professions",
           "Miscellaneous"]

NED_Df["Occupation Group"] = np.select(conditions, choices, default="Other")
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3141658363.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Occupation Group"] = np.select(conditions, choices, default="Other")
#      Age       Nationality Current Residence     Occupation  \
# 0     21           Belgian           Ireland       Student
# 1     22            German           Ireland       Student
# 2     25  Dual citizenship           Ireland        Student
# 3     22            German           Ireland        Student
# 4     61            German           Germany  Civilengineer
# ..   ...               ...               ...            ...
# 229   51            German             Spain          None
# 230   23            German           Germany       Student
# 231   22            German           Germany        Student
# 232   22             Swiss       Switzerland        Student
# 233   23         Sri lanka       Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                                      Bulky Luggage  \
# 0    No, I don’t use bulky luggage when traveling
# 1                                              NaN
# 2                                               No
# 3                                              NaN
# 4                                               No
# ..                                             ...
# 229                                            NaN
# 230                                            NaN
# 231                                            NaN
# 232                                            NaN
# 233                                        Clothes
#
#     Luggage Buying Plans (next year) Plan-to-buy Luggage Repacking Luggage  \
# 0                                 No                   /               Yes
# 1                                 No                 NaN               Yes
# 2                                 No                 NaN               Yes
# 3                                 No                 NaN               Yes
# 4                                 No                 NaN                No
# ..                               ...                 ...               ...
# 229                               No                 NaN               Yes
# 230                               No                 NaN               Yes
# 231                               No                 NaN               Yes
# 232                               No                 NaN               Yes
# 233                               No                 NaN               Yes
#
#      ... Misplaced Luggage by Airlines Smart Luggage Owner  \
# 0    ...                            No                  No
# 1    ...                           Yes                  No
# 2    ...                           Yes                  No
# 3    ...                            No                  No
# 4    ...                           Yes                  No
# ..   ...                           ...                 ...
# 229  ...                           Yes                  No
# 230  ...                           Yes                 Yes
# 231  ...                           Yes                  No
# 232  ...                           Yes                  No
# 233  ...                            No                  No
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range  \
# 0                                             31-45     16-24
# 1                                             61-75     16-24
# 2                                             46-60     25-33
# 3                                             46-60     16-24
# 4                                             31-45       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
#             Occupation Group
# 0                   Students
# 1                   Students
# 2                   Students
# 3                   Students
# 4    Engineering Professions
# ..                       ...
# 229                  Unknown
# 230                 Students
# 231                 Students
# 232                 Students
# 233                 Students
#
# [231 rows x 21 columns]

# %%
NED_Df["Occupation Group"].unique()
# Out:
# array(['Students', 'Engineering Professions', 'Management Professions',
#        'Creative and Design Professions', 'Homemakers',
#        'Healthcare Professions', 'Hospitality Professions',
#        'Social Professions', 'Education Professions', 'Unknown',
#        'Advisory and Consulting Professions', 'Retired',
#        'Finance and Banking', 'Miscellaneous', 'Other', 'Researcher',
#        'Marketing Professions', 'Governmental Professions',
#        'Architecture Professions'], dtype=object)

# %%
occupation_counts = NED_Df["Occupation Group"].value_counts()

plt.pie(occupation_counts, labels=occupation_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Occupation')
plt.show()

# %%
occupation_counts
# Out:
# Students                               115
# Management Professions                  29
# Creative and Design Professions         12
# Homemakers                              10
# Healthcare Professions                   9
# Education Professions                    9
# Advisory and Consulting Professions      9
# Retired                                  7
# Hospitality Professions                  6
# Other                                    5
# Miscellaneous                            5
# Unknown                                  3
# Engineering Professions                  3
# Finance and Banking                      2
# Researcher                               2
# Marketing Professions                    2
# Social Professions                       1
# Governmental Professions                 1
# Architecture Professions                 1
# Name: Occupation Group, dtype: int64

# %%
occupation_counts.sum()
# Out:
# 231

# %%
travel_frequency_counts = NED_Df["Travel per year"].value_counts()

plt.pie(travel_frequency_counts, labels=travel_frequency_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Travel Frequency')
plt.show()

# %%
travel_frequency_counts
# Out:
# More than 15 times    65
# 4-6                   48
# 10-15                 41
# 7-9                   39
# 1-3                   38
# Name: Travel per year, dtype: int64

# %%
NED_Df["Bulky Luggage"].unique()
# Out:
# array(['No, I don’t use bulky luggage when traveling ', nan, 'No',
#        'Snowboard ',
#        'For long vacation, I usually use a middle seize suitcase. For less than 2 weeks I like to use a backpack. ',
#        'no', 'Clothes and personal belongings ',
#        'Kartons when bringing items from home country',
#        'Only for very long trips', 'Racing Bike', 'All of my luggage',
#        'I do when I go back to Germany. Mostly for bringing back German products (food, cosmetics, etc)',
#        'Suitcase if I have to take large amounts of clothing, gifts, etc.',
#        'Bike', 'When moving to a new place, otherwise I try to avoid it.',
#        'Hiking sticks', 'Suitcase ',
#        'Rarely, only if travelling for a month or more.',
#        'Only for a festival but not regularly ',
#        'Clothes, Books, Electronical devices, usual travel objects',
#        'when I move countries', 'Usually not', 'Scuba Equipment ', 'Dog',
#        'only for longer travels (eg big suitcase) by plane, happens once in a couple of years',
#        'Child Seat', 'clothing',
#        'for longer holidays (~10+ days), I use a big suitcase',
#        'For longer vacations and when I moved from Germany to Spain, so mostly clothes ',
#        'If you travel for a longer period of stuff, you simply need more space',
#        'Sirfboard', 'Yes, instruments',
#        'No, I only travel with small luggage',
#        'Clothing, expansive things ', 'Clothes', 'Not really',
#        'Yes, for longer travel periods. Mostly for clothes and liquid (skin) care products >100ml when traveling by plane.',
#        'No not really', 'Clothes an co. ', 'Suitcase for clothes',
#        'clothing, camera equipment, shoes, liquids, climbing gear',
#        'Golf', 'Apart from a checked suitcase, no.', 'Mostly not ',
#        'Longer trips, clothes and gifts', 'Cloths', 'normally not ',
#        'Clothes ', 'Only if  necessary ',
#        'Not necessarily unless its for a long stay, it is usually clothes',
#        "No, I don't.", 'For fragile items', 'Clothing shoes toilettery',
#        'Various', 'no, i hate too much luggage',
#        'Shoes, coats, heavier clothing, sports equipment ',
#        'Sometimes Golf Equipment ', 'Surfboards ', 'Ski',
#        'Yes, for Sports equipment', 'No '], dtype=object)

# %%
values_to_replace = ["nan",'No, I don’t use bulky luggage when traveling ','No','No ','no, i hate too much luggage',"No, I don't.",'All of my luggage', 'Suitcase ','Not necessarily unless its for a long stay, it is usually clothes','normally not ','Mostly not ','Not really ','Apart from a checked suitcase, no.','No not really','Not really','No, I only travel with small luggage','Usually not','no']  
NED_Df["Bulky Luggage"].replace(values_to_replace, "No", inplace=True)

values_to_replace_clothes = ['Clothes','Clothes, Books, Electronical devices, usual travel objects','Clothes ','Clothes and Personal Belonging','Shoes, coats, heavier clothing, sports equipment ','Clothes and personal belongings ','clothing','Clothing, expansive things ', 'Clothes an co. ','Suitcase for clothes','Clothing shoes toilettery','Cloths','normally not ','Mainly clothes and vanity bag(s)','clothing, camera equipment, shoes, liquids, climbing gear']  
NED_Df["Bulky Luggage"].replace(values_to_replace_clothes, "Clothes and Personal Belonging", inplace=True)

values_to_replace_sport = ['Snowboard ','Racing Bike','Bike','Hiking sticks','Scuba Equipment ','Yes, for Sports equipment','Sirfboard','Golf','Sometimes Golf Equipment ', 'Surfboards ', 'Ski']  
NED_Df["Bulky Luggage"].replace(values_to_replace_sport, "Sport Equipment", inplace=True)

values_to_replace_moving = ['Kartons when bringing items from home country','I do when I go back to Germany. Mostly for bringing back German products (food, cosmetics, etc)','Suitcase if I have to take large amounts of clothing, gifts, etc.','When moving to a new place, otherwise I try to avoid it.','when I move countries']  
NED_Df["Bulky Luggage"].replace(values_to_replace_moving, "Moving Purpose", inplace=True)

values_to_replace_vacation = ['Yes, for longer travel periods. Mostly for clothes and liquid (skin) care products >100ml when traveling by plane.','For long vacation, I usually use a middle seize suitcase. For less than 2 weeks I like to use a backpack. ','Only for very long trips','Rarely, only if travelling for a month or more.','Only for a festival but not regularly ','only for longer travels (eg big suitcase) by plane, happens once in a couple of years','for longer holidays (~10+ days), I use a big suitcase','For longer vacations and when I moved from Germany to Spain, so mostly clothes ','If you travel for a longer period of stuff, you simply need more space','Longer trips, clothes and gifts']  
NED_Df["Bulky Luggage"].replace(values_to_replace_vacation, "Longer Vacation", inplace=True)

values_to_replace_instruments = ['Yes, instruments']  
NED_Df["Bulky Luggage"].replace(values_to_replace_instruments, "Instruments", inplace=True)

values_to_replace_big_things = ['Child Seat','For fragile items']  
NED_Df["Bulky Luggage"].replace(values_to_replace_big_things, "Bulky and Fragile Things", inplace=True)

values_to_replace_animals = ['Dog']  
NED_Df["Bulky Luggage"].replace(values_to_replace_animals, "Animals", inplace=True)

values_to_replace_other = ['Only if  necessary ','Various']  
NED_Df["Bulky Luggage"].replace(values_to_replace_other, "Other", inplace=True)

NED_Df["Bulky Luggage"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace, "No", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_clothes, "Clothes and Personal Belonging", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_sport, "Sport Equipment", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_moving, "Moving Purpose", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_vacation, "Longer Vacation", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_instruments, "Instruments", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_big_things, "Bulky and Fragile Things", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_animals, "Animals", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1138212025.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bulky Luggage"].replace(values_to_replace_other, "Other", inplace=True)
# array(['No', nan, 'Sport Equipment', 'Longer Vacation',
#        'Clothes and Personal Belonging', 'Moving Purpose', 'Animals',
#        'Bulky and Fragile Things', 'Instruments', 'Other'], dtype=object)

# %%
bulky_luggage_counts = NED_Df["Bulky Luggage"].value_counts()

plt.pie(bulky_luggage_counts, labels=bulky_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Bulky Luggage Usage')
plt.show()

# %%
bulky_luggage_counts
# Out:
# No                                80
# Clothes and Personal Belonging    14
# Sport Equipment                   11
# Longer Vacation                   10
# Moving Purpose                     5
# Bulky and Fragile Things           2
# Other                              2
# Animals                            1
# Instruments                        1
# Name: Bulky Luggage, dtype: int64

# %%
NED_Df["Plan-to-buy Luggage"].unique()
# Out:
# array(['/', nan, 'Suitcase (checkin luggage))',
#        "I love buying bags so I guess I'll buy something at some point ",
#        'Lightweight suitcase', 'Big suitcase, current one broke',
#        'Current one broke', 'Bag for carry on',
#        'Suitcase, mid-size; old one worn off', 'A new laptop backpack',
#        'a suitcase because my current ones are old',
#        'suitcase because mine is too small',
#        'Bag with wheels, light weight, easy to carry ',
#        'Carry on suitcase', 'Suitcase and carry on trolkey',
#        'Hard shell suitcase for a longer trip',
#        'Carry On suite case, don’t have one in Dublin',
#        'Suitcase with 4 wheels', 'Backpack',
#        'suitcase set (I need a business set)',
#        'Backpack (about 50 litre)',
#        'New suitcase because my old one broke', 'meidum-size suitcase',
#        'Bigger Backback for a backpacking trip ', 'Suitcase (carry on)',
#        'Case for bicycle', 'A backpack for hand luggage', 'Suitcase ',
#        'check in luggage',
#        'suitcase (checked-in luggage) as my old one is quite old and starts to fall apart in places',
#        'A small hand luggage suitcase (to be taken in the plane), because it costs less than a regular big suitcase (and is even free with some airlines)',
#        'Duffel bag because old one is damaged',
#        'Suitcase in very light fabric', 'Rimowa suitcase ',
#        'suitcase, wear an tear', 'No', 'Suitcase (check-in)',
#        'A lighter suitcase for maximising the benefits of carry-on luggage ',
#        'Carey on suitcase',
#        'New carry on suitcase because my current one is damaged ',
#        'Replacing an old suitcase',
#        'New suitcase as my old one is not the best anymore (old)',
#        'suitcase (carry on)', 'Carry on suitcase ', 'carry on suitcase ',
#        'Soft case ', 'Carry-on suitcase',
#        'Rimowa - because of the good quality (light and long lasting)',
#        'Small carry on because the handle on the old one is faulty',
#        'Carry on suitcase, travel frequency will increase due to new job',
#        'suitcase for flights',
#        'Suitcase with wheels for both check in and hand carry. The current suitcase is falling apart.',
#        'Bigger backpack... My current backpack ist to small and not comfortable ',
#        'Handluggage because mine is broken ',
#        'Bigger suitcase as my old one needs to be renewed '], dtype=object)

# %%
values_to_replace_small_suitcase = ['Carry on suitcase ','Suitcase (carry on)','Small carry on because the handle on the old one is faulty','Carry on suitcase, travel frequency will increase due to new job','suitcase for flights''Carry on suitcase ', 'carry on suitcase ','Soft case ', 'Carry-on suitcase','suitcase (carry on)','New carry on suitcase because my current one is damaged ','Carey on suitcase','A lighter suitcase for maximising the benefits of carry-on luggage ','Suitcase in very light fabric','A small hand luggage suitcase (to be taken in the plane), because it costs less than a regular big suitcase (and is even free with some airlines)','Carry On suite case, don’t have one in Dublin','Suitcase and carry on trolkey','Carry on suitcase']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_small_suitcase, "Carry-on Suitcase", inplace=True)

values_to_replace_suitcase = ['Suitcase (check-in)','suitcase (checked-in luggage) as my old one is quite old and starts to fall apart in places','check in luggage','Suitcase ','New suitcase because my old one broke', 'meidum-size suitcase','Hard shell suitcase for a longer trip','a suitcase because my current ones are old','suitcase because mine is too small','Suitcase, mid-size; old one worn off','Suitcase (checkin luggage))','Lightweight suitcase', 'Big suitcase, current one broke']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_suitcase, "Check-in Suitcase", inplace=True)

values_to_replace_backpack = ['Backpack','A backpack for hand luggage']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_backpack, "Backpack (small)", inplace=True)

values_to_replace_suitcase_set = ['suitcase set (I need a business set)']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_suitcase_set, "Suitcase Set", inplace=True)

values_to_replace_big_backpack = ['Bigger Backback for a backpacking trip ','Bigger backpack... My current backpack ist to small and not comfortable ','Backpack (about 50 litre)']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_big_backpack, "Backpack(big)", inplace=True)

values_to_replace_dufflebag = ['Duffel bag because old one is damaged']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_dufflebag, "Dufflebag", inplace=True)

values_to_replace_bag_wheels = ['Bag with Wheely','Suitcase with wheels for both check in and hand carry. The current suitcase is falling apart.','Bag with wheels, light weight, easy to carry ']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_bag_wheels, "Bag with Wheels", inplace=True)

values_to_replace_old = ['Handluggage because mine is broken ','Bigger suitcase as my old one needs to be renewed ','New suitcase as my old one is not the best anymore (old)','Suitcase, because I want to get a better one with more quality ','Replacing an old suitcase','suitcase, wear an tear']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_old, "Replacing Old Luggage", inplace=True)

values_to_replace_no = ['/']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_no, "No", inplace=True)

values_to_replace_other = ["I love buying bags so I guess I'll buy something at some point ",'suitcase for flights','Rimowa - because of the good quality (light and long lasting)','suitcase, wear an tear','Rimowa suitcase ','Case for bicycle','Suitcase with 4 wheels','Current one broke','Bag for carry on','A new laptop backpack']  
NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_other, "Other", inplace=True)

NED_Df["Plan-to-buy Luggage"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_small_suitcase, "Carry-on Suitcase", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_suitcase, "Check-in Suitcase", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_backpack, "Backpack (small)", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_suitcase_set, "Suitcase Set", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_big_backpack, "Backpack(big)", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_dufflebag, "Dufflebag", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_bag_wheels, "Bag with Wheels", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_old, "Replacing Old Luggage", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_no, "No", inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2622690286.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Plan-to-buy Luggage"].replace(values_to_replace_other, "Other", inplace=True)
# array(['No', nan, 'Check-in Suitcase', 'Other', 'Bag with Wheels',
#        'Carry-on Suitcase', 'Backpack (small)', 'Suitcase Set',
#        'Backpack(big)', 'Dufflebag', 'Replacing Old Luggage'],
#       dtype=object)

# %%
buying_luggage_counts = NED_Df["Plan-to-buy Luggage"].value_counts()

plt.bar(buying_luggage_counts.index, buying_luggage_counts, color='turquoise', width=0.3)
plt.title('Buying Luggage Plans')
plt.xticks(fontsize=5)
plt.show()

# %%
buying_luggage_counts
# Out:
# Carry-on Suitcase        16
# Check-in Suitcase        13
# Other                     9
# Replacing Old Luggage     5
# Backpack(big)             3
# No                        2
# Bag with Wheels           2
# Backpack (small)          2
# Suitcase Set              1
# Dufflebag                 1
# Name: Plan-to-buy Luggage, dtype: int64

# %%
buy_luggage_counts = NED_Df["Plan-to-buy Luggage"].value_counts()

plt.pie(buy_luggage_counts, labels=buy_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Buying Plans')
plt.show()

# %%
repacking_luggage_counts = NED_Df["Repacking Luggage"].value_counts()

plt.pie(repacking_luggage_counts, labels=repacking_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Repacking Luggage')
plt.show()

# %%
repacking_luggage_counts
# Out:
# Yes    143
# No      88
# Name: Repacking Luggage, dtype: int64

# %%
forgotten_luggage_counts = NED_Df["Forgotten luggage"].value_counts()

plt.pie(forgotten_luggage_counts, labels=forgotten_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Forgotten Luggage')
plt.show()

# %%
forgotten_luggage_counts
# Out:
# No     204
# Yes     27
# Name: Forgotten luggage, dtype: int64

# %%
misplaced_luggage_counts = NED_Df["Misplaced Luggage by Airlines"].value_counts()

plt.pie(misplaced_luggage_counts, labels=misplaced_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Misplaced Luggage by Airlines')
plt.show()

# %%
misplaced_luggage_counts
# Out:
# No     130
# Yes    101
# Name: Misplaced Luggage by Airlines, dtype: int64

# %%
smart_luggage_owner_counts = NED_Df["Smart Luggage Owner"].value_counts()

plt.pie(smart_luggage_owner_counts, labels=smart_luggage_owner_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Smart Luggage Owner')
plt.show()

# %%
smart_luggage_owner_counts
# Out:
# No     200
# Yes     31
# Name: Smart Luggage Owner, dtype: int64

# %%
airTag_counts = NED_Df["AirTag Users"].value_counts()

plt.pie(airTag_counts, labels=airTag_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of AirTag Users')
plt.show()

# %%
airTag_counts
# Out:
# No     184
# Yes     47
# Name: AirTag Users, dtype: int64

# %%
NED_Df["Price Sensitivity for a Add-on Digital Solution"].unique()
# Out:
# array(['31-45', '61-75', '46-60', '1-15',
#        'I would not buy such a solution', '16-30', 'Above 100 euros',
#        '76-100', '16-30 euros', '61-75 €', '31-45 €', '16-30 €', '1-15 €',
#        '46-60 €', 'Above 100 €', '76-100 €'], dtype=object)

# %%
values_to_replace_1 = ['1-15']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_1, '1-15 €', inplace=True)

values_to_replace_2 = ['16-30','16-30 euros']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_2, '16-30 €', inplace=True)

values_to_replace_3 = ['31-45']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_3, '31-45 €', inplace=True)

values_to_replace_4 = ['46-60']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_4, '46-60 €', inplace=True)

values_to_replace_5 = ['61-75']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_5, '61-75 €', inplace=True)

values_to_replace_6 = ['76-100']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_6, '76-100 €', inplace=True)

values_to_replace_7 = ['Above 100 euros']  
NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_7, 'Above 100 €', inplace=True)


NED_Df["Price Sensitivity for a Add-on Digital Solution"].unique()
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_1, '1-15 €', inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_2, '16-30 €', inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_3, '31-45 €', inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_4, '46-60 €', inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_5, '61-75 €', inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_6, '76-100 €', inplace=True)
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2413945074.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Price Sensitivity for a Add-on Digital Solution"].replace(values_to_replace_7, 'Above 100 €', inplace=True)
# array(['31-45 €', '61-75 €', '46-60 €', '1-15 €',
#        'I would not buy such a solution', '16-30 €', 'Above 100 €',
#        '76-100 €'], dtype=object)

# %%
price_sensitivity_counts = NED_Df["Price Sensitivity for a Add-on Digital Solution"].value_counts()

plt.pie(price_sensitivity_counts, labels=price_sensitivity_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Price Sensitivity')
plt.show()

# %%
price_sensitivity_counts
# Out:
# 31-45 €                            59
# 16-30 €                            56
# 46-60 €                            38
# I would not buy such a solution    29
# 1-15 €                             22
# 76-100 €                           13
# 61-75 €                             8
# Above 100 €                         6
# Name: Price Sensitivity for a Add-on Digital Solution, dtype: int64

# %%
NED_Df["Kind of Smart Luggage"].unique()
# Out:
# array(['/', nan, 'Because it was time to replace the old\nSuitcase ',
#        'Because it’s  light', 'Suitcase(es) with TSA lock',
#        'TSA lock on carry on', 'TSA approved locks ',
#        'A smal suitcase for a 4 day trip',
#        'Samsonite ecodriver for a vacation and for the weekend/short vacation',
#        'usb charging port, was included lol', 'Laptop bag',
#        'TSA lock, for security while traveling USB charging port ',
#        'My Cabin Luggage is smart. Bought it because of the TSA Lock (could be opened from customs without assistance from my side) and made it smart on my own with an AirTag ',
#        'A TSA-approved lock to make travelling more accessible in case my luggage has to be accessed without me being around. ',
#        'TSA locks, for convenience & safety', 'Away hardshell carry-o ',
#        'Tumi bag', 'Usb charging (gift)',
#        'TSA approved and use an AirTag for my bag ',
#        'Suitcase with integrated location tracking',
#        'It happened to have smart features, but I did not buy it because of its smart features. ',
#        '-', 'Suitcases,  mandatory on flights ', 'TSA Lock ',
#        'TSA approved lock (none of the other characteristics mentioned)',
#        'Samsung, because I needed a new carry on suitcase',
#        'Backpack. Good looks. ', 'Away bag at the Away store',
#        'TSA approved lock - for traveling to the US', 'TSA-approved lock',
#        'carry-on suitcase with tsa lock',
#        'A bag with a charging port for for independent travel without worrying about the battery '],
#       dtype=object)

# %%
TSA_lock = ['Away hardshell carry-o','Away bag at the Away store','TSA approved lock - for traveling to the US','TSA-approved lock','carry-on suitcase with tsa lock','Suitcase(es) with TSA lock','TSA lock on carry on','TSA approved locks','TSA lock, for security while traveling USB charging port','My Cabin Luggage is smart. Bought it because of the TSA Lock (could be opened from customs without assistance from my side) and made it smart on my own with an AirTag ','A TSA-approved lock to make travelling more accessible in case my luggage has to be accessed without me being around.','TSA locks, for convenience & safety','TSA approved and use an AirTag for my bag']
usb_charging =['usb charging port, was included lol','Usb charging (gift)']
tracking = ['Suitcase with integrated location tracking']
more_than_one_smart_feature = ['Backpack. Good looks.','Samsung, because I needed a new carry on suitcase','Suitcases, mandatory on flights','Tumi bag','A smal suitcase for a 4 day trip','Samsonite ecodriver for a vacation and for the weekend/short vacation']


conditions = [
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, TSA_lock)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, usb_charging)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, tracking)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, more_than_one_smart_feature)),
]


choices = ["TSA Lock", "USB Charging Port", "Tracking Feature", "More than one Feature"]

NED_Df["Bought Smart Luggage Type"] = np.select(conditions, choices, default="No")
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\1112698584.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Bought Smart Luggage Type"] = np.select(conditions, choices, default="No")
#      Age       Nationality Current Residence     Occupation  \
# 0     21           Belgian           Ireland       Student
# 1     22            German           Ireland       Student
# 2     25  Dual citizenship           Ireland        Student
# 3     22            German           Ireland        Student
# 4     61            German           Germany  Civilengineer
# ..   ...               ...               ...            ...
# 229   51            German             Spain          None
# 230   23            German           Germany       Student
# 231   22            German           Germany        Student
# 232   22             Swiss       Switzerland        Student
# 233   23         Sri lanka       Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                       Bulky Luggage Luggage Buying Plans (next year)  \
# 0                                No                               No
# 1                               NaN                               No
# 2                                No                               No
# 3                               NaN                               No
# 4                                No                               No
# ..                              ...                              ...
# 229                             NaN                               No
# 230                             NaN                               No
# 231                             NaN                               No
# 232                             NaN                               No
# 233  Clothes and Personal Belonging                               No
#
#     Plan-to-buy Luggage Repacking Luggage  ... Smart Luggage Owner  \
# 0                    No               Yes  ...                  No
# 1                   NaN               Yes  ...                  No
# 2                   NaN               Yes  ...                  No
# 3                   NaN               Yes  ...                  No
# 4                   NaN                No  ...                  No
# ..                  ...               ...  ...                 ...
# 229                 NaN               Yes  ...                  No
# 230                 NaN               Yes  ...                 Yes
# 231                 NaN               Yes  ...                  No
# 232                 NaN               Yes  ...                  No
# 233                 NaN               Yes  ...                  No
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range  \
# 0                                           31-45 €     16-24
# 1                                           61-75 €     16-24
# 2                                           46-60 €     25-33
# 3                                           46-60 €     16-24
# 4                                           31-45 €       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
#             Occupation Group Bought Smart Luggage Type
# 0                   Students                        No
# 1                   Students                        No
# 2                   Students                        No
# 3                   Students                        No
# 4    Engineering Professions                        No
# ..                       ...                       ...
# 229                  Unknown                        No
# 230                 Students                        No
# 231                 Students                        No
# 232                 Students                        No
# 233                 Students                        No
#
# [231 rows x 22 columns]

# %%
NED_Df["Bought Smart Luggage Type"].unique()
# Out:
# array(['No', 'TSA Lock', 'More than one Feature', 'USB Charging Port',
#        'Tracking Feature'], dtype=object)

# %%
bought_smart_luggage_counts = NED_Df["Bought Smart Luggage Type"].value_counts()

plt.bar(bought_smart_luggage_counts.index, bought_smart_luggage_counts, color='purple', width=0.3)
plt.title("Bought Smart Luggage Type")
plt.xticks(fontsize=7)
plt.show()

# %%
bought_smart_luggage_counts
# Out:
# No                       211
# TSA Lock                  12
# More than one Feature      5
# USB Charging Port          2
# Tracking Feature           1
# Name: Bought Smart Luggage Type, dtype: int64

# %%
filtered_df = NED_Df[NED_Df["Bought Smart Luggage Type"] != 'No']

bought_smart_luggage_counts = filtered_df["Bought Smart Luggage Type"].value_counts()

plt.bar(bought_smart_luggage_counts.index, bought_smart_luggage_counts, color='purple', width=0.3)
plt.title("Bought Smart Luggage Type")
plt.xticks(fontsize=7)
plt.show()

# %%
plt.pie(bought_smart_luggage_counts, labels=bought_smart_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Bought Smart Luggage Type')
plt.show()

# %%
replacing_old_luggage = ['Because it was time to replace the old\nSuitcase','Samsung, because I needed a new carry on suitcase']
light_weight =['Because it’s  light']
security = ['TSA lock, for security while traveling USB charging port',"TSA locks, for convenience & safety"]
no_excplicit_reason = ['usb charging port, was included lol','It happened to have smart features, but I did not buy it because of its smart features.']
looking = ['Backpack. Good looks.']
damage_prevention_airport_security = ['My Cabin Luggage is smart. Bought it because of the TSA Lock (could be opened from customs without assistance from my side) and made it smart on my own with an AirTag','A TSA-approved lock to make travelling more accessible in case my luggage has to be accessed without me being around.']


conditions = [
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, replacing_old_luggage)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, light_weight)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, security)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, no_excplicit_reason)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, looking)),
    NED_Df["Kind of Smart Luggage"].str.strip().str.lower().isin(map(str.lower, damage_prevention_airport_security))
]


choices = ["Replacing Old Luggage", "Light Weight", "Security Reasons", "No Explicit Reason", "Design", "Damage Prevention from Airport Security"]

NED_Df["Reasons for Buying Smart Luggage Type"] = np.select(conditions, choices, default="No")
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\3033620866.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Reasons for Buying Smart Luggage Type"] = np.select(conditions, choices, default="No")
#      Age       Nationality Current Residence     Occupation  \
# 0     21           Belgian           Ireland       Student
# 1     22            German           Ireland       Student
# 2     25  Dual citizenship           Ireland        Student
# 3     22            German           Ireland        Student
# 4     61            German           Germany  Civilengineer
# ..   ...               ...               ...            ...
# 229   51            German             Spain          None
# 230   23            German           Germany       Student
# 231   22            German           Germany        Student
# 232   22             Swiss       Switzerland        Student
# 233   23         Sri lanka       Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                       Bulky Luggage Luggage Buying Plans (next year)  \
# 0                                No                               No
# 1                               NaN                               No
# 2                                No                               No
# 3                               NaN                               No
# 4                                No                               No
# ..                              ...                              ...
# 229                             NaN                               No
# 230                             NaN                               No
# 231                             NaN                               No
# 232                             NaN                               No
# 233  Clothes and Personal Belonging                               No
#
#     Plan-to-buy Luggage Repacking Luggage  ...  \
# 0                    No               Yes  ...
# 1                   NaN               Yes  ...
# 2                   NaN               Yes  ...
# 3                   NaN               Yes  ...
# 4                   NaN                No  ...
# ..                  ...               ...  ...
# 229                 NaN               Yes  ...
# 230                 NaN               Yes  ...
# 231                 NaN               Yes  ...
# 232                 NaN               Yes  ...
# 233                 NaN               Yes  ...
#
#                                  Kind of Smart Luggage  \
# 0                                                    /
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 229                                                NaN
# 230  A bag with a charging port for for independent...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range  \
# 0                                           31-45 €     16-24
# 1                                           61-75 €     16-24
# 2                                           46-60 €     25-33
# 3                                           46-60 €     16-24
# 4                                           31-45 €       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
#             Occupation Group Bought Smart Luggage Type  \
# 0                   Students                        No
# 1                   Students                        No
# 2                   Students                        No
# 3                   Students                        No
# 4    Engineering Professions                        No
# ..                       ...                       ...
# 229                  Unknown                        No
# 230                 Students                        No
# 231                 Students                        No
# 232                 Students                        No
# 233                 Students                        No
#
#     Reasons for Buying Smart Luggage Type
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                      No
# ..                                    ...
# 229                                    No
# 230                                    No
# 231                                    No
# 232                                    No
# 233                                    No
#
# [231 rows x 23 columns]

# %%
NED_Df["Reasons for Buying Smart Luggage Type"].unique()
# Out:
# array(['No', 'Replacing Old Luggage', 'Light Weight',
#        'No Explicit Reason', 'Security Reasons',
#        'Damage Prevention from Airport Security', 'Design'], dtype=object)

# %%
reasons_bought_smart_luggage_counts = NED_Df["Reasons for Buying Smart Luggage Type"].value_counts()

plt.bar(reasons_bought_smart_luggage_counts.index, reasons_bought_smart_luggage_counts, color='blue', width=0.3)
plt.title("Reasons for Smart Luggage Purchase")
plt.xticks(fontsize=5)
plt.show()

# %%
reasons_bought_smart_luggage_counts
# Out:
# No                                         221
# Replacing Old Luggage                        2
# No Explicit Reason                           2
# Security Reasons                             2
# Damage Prevention from Airport Security      2
# Light Weight                                 1
# Design                                       1
# Name: Reasons for Buying Smart Luggage Type, dtype: int64

# %%
filtered_df2 = NED_Df[NED_Df["Reasons for Buying Smart Luggage Type"] != 'No']

reasons_for_bought_smart_luggage_counts = filtered_df2["Reasons for Buying Smart Luggage Type"].value_counts()

plt.bar(reasons_for_bought_smart_luggage_counts.index, reasons_for_bought_smart_luggage_counts, color='blue', width=0.3)
plt.title("Reasons for Smart Luggage Purchase")
plt.xticks(fontsize=7)
plt.show()

# %%
plt.pie(reasons_for_bought_smart_luggage_counts, labels=reasons_for_bought_smart_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Distribution of Reasons for Smart Luggage Purchase')
plt.show()

# %%
NED_Df["Prevention from Buying Smart Luggage"].unique()
# Out:
# array(['The pieces of luggage I own still have a lot of life in them and I therefore don’t want to spend the money on a new piece of smart luggage ',
#        'Price, Design, weight of luggage',
#        'Currently no smart hiking backpacks ',
#        'Only one feature per solution and too expensive for only one feature',
#        'No time', 'I have Apple AirTags',
#        'Never thought about it. I am happy with the stuff I own right now (1 medium, 1 large suitcase, 1 30l backpack, 1 55l backpack)',
#        'Yet no time and no offer',
#        'Right now not necessary. I would purchase a smart luggage as soon as needed.',
#        'Never thought of it', 'Self-worth', nan,
#        'No need for it, did not know about it ',
#        'I would like to have one', 'Didnt see the need until now',
#        'Only few problems ', 'Price?', 'Availability and information ',
#        'I don’t need it', 'I dont know wäre to buy ',
#        'Do not need extra luggage at the moment ', 'Did not buy it yet',
#        'It’s on my list', '  I just haven’t looked into those yet',
#        'My luggage is to new to replace ',
#        'In fact: my next piece of luggage will be smart. I just need to buy it eventually…',
#        'Still got my good suitcases', 'no idea',
#        'Didn’t think about it yet ', 'My old luggage is perfectly intact',
#        'my suitcase is fine for years, so i don‘t need a new one',
#        'No need',
#        "Too expensive and also I don't see the point to be honest ",
#        'No need for new luggage at the moment', 'Haven‘ t think about it',
#        'What is a smart luggage?', 'Nothing ',
#        "I have enough pieces, don't need anything else.",
#        "Didn't know it existed", 'Don’t know if I need it',
#        'I rarely check in luggage.', 'No need for new luggage. ',
#        'No need because of infrequent air travel',
#        'I did not know that they exist', 'High Price ', 'Money',
#        'I didn’t know it existed.',
#        "I have never felt the need to own it, I have other ways of covering for these needs, e.g. power banks, locks etc. I'm not opposed to it though.",
#        'I never heard about it. I try to pack as light as possible. ',
#        "I don't need one/ am content with the luggage I currently have",
#        "I don't need it for my travelling. ",
#        'Not necessary (travelling by train)',
#        'I already have enough suitcases etc hence it would be an unnecessary expense',
#        'No trust', "I don't need it, often the quality is bad",
#        "I don't feel like it's necessary for my needs. Right now, I travel mostly with carry-on luggage, hence no need of a tracking device, and I don't fly often, so no need of a built-in scale.",
#        'Does not feel necessary to me.',
#        'I have never heard of smart luggage before ',
#        'did not know it existed', 'The need and price',
#        'I already have the luggage I need, and buying a new one ist too expensive ',
#        'Price', 'Never heard of it before ',
#        'Haven’t had the news for it so far ',
#        'No need for a new piece of luggage',
#        'Currently no need for smart luggage',
#        'I never had any issues with my luggages.',
#        "Frankly, no need. I do not travel by air frequently and I normally don't lose my luggage otherwise. And I can charge my phone at home...",
#        'Expensive and I don’t need it ',
#        'I don’t need a new piece of luggage right now - my used pieces of luggage are still in a good condition',
#        'The price and the fact that I already own good quality suitcases. ',
#        'No need for a new luggage ', 'Too expensive ',
#        'No need / expensive',
#        'I have my suitcases and don’t need new ones ',
#        'No desperate need for it', 'Don’t need it ',
#        'I did not know it exists',
#        'No need for new equipment. Might consider when I need new one',
#        'no need so far', 'Pricing - battery is too heavy',
#        'no need to buy a new piece of luggage since mine are fully functional. If buying a new one in a couple of years, I might consider buying smart luggage depending on the price',
#        'No interest', "Didn't know about it ",
#        'For me it’s fancy but not necessary', "don't trust smart devices",
#        'No need for it',
#        "I like my dufffle bag and I don't have the need for USB ports and stuff like that on my bag or backpack",
#        'no need to spend money on luggage because I currently own suitcases; do not use a large suitcase frequently enough to warrant spending more money on smart features; never misplaced my backpack/carry-on and always bring it with me so no real need for a tracking function; own a suitcase scale',
#        'Restrictions from airlines',
#        'I don‘t think I need it, but I haven’t given it much thought before',
#        'I so far have not felt like I needed it but it also has not been on my radar',
#        'That I already own a normal suitcase/bag',
#        'Have not bought a new suitcase',
#        'Upgrade after sale, e.g. Apple Location Chip',
#        'Never thought about it, never felt like I needed something other than regular luggage',
#        'No benefit', 'information, what’s the benefit , price?',
#        "i didn't know something like that exists and i never felt ne need of one",
#        "Don't need yet",
#        "haven't considered it, no recent purchases of new luggage ",
#        'I don’t need it ', 'To avoid problems with airline ',
#        'Too expensive', 'I never felt like I need it',
#        'No need for it and higher cost ',
#        'So far I am fine with my suitcase/backpack. I travel with stuff that wouldn’t be an issue if lost. ',
#        "Didn't think about it but probably also the price",
#        'All available without smart luggage ', 'Don’t see the need',
#        'AirTag can do same ',
#        'No need so far/ didn’t know the categorie ',
#        'I own well-working existing luggage and therefore don´t have a strong need for replacing them just to add smart elements that I could at least partially replace otherwise.',
#        'No necessary ', 'I dont See the Benefit ',
#        'Haven’t even really heard about it until now. So what’s preventing me: Lack of knowledge; probably price since I expect them to be rather expensive ',
#        'Don’t need that shit', 'I don‘t think it is super necessary',
#        'No needed', 'Never thought about', 'I already have other luggage',
#        'Money ', 'Most likely the price', "I don't really need it",
#        'I am content with the luggage I already own', 'Never heard of it',
#        'Didnt know it exists', "I didn't needed it untill now",
#        'The fire and safety risk it still poses on board as well as the price ',
#        'Hadn’t heard about it', 'No need ',
#        'Use of AirTag sufficient for my need',
#        "I have had my luggage for a long time. It still works so I don't plan on buying anything new. ",
#        'The price and that I dont think I need it',
#        'Life span of the device ', 'Don’t need new suitcase',
#        'Prices and already owning a lot of luggage ', 'Price/Design',
#        'i have enough of the old ones and no need yet to buy immediately an additional new one',
#        'Cost', 'didn’t need anything new the last years ',
#        'My old one still works ', 'No idea',
#        'I still have perfectly good luggage and bought a small handheld scale. Works great',
#        '-', 'Old suitcase is not broken ',
#        'nothing, just have not done it yet', 'No need for now',
#        "Haven't considered it yet, too expensive ",
#        "I didn't know about that type of luggage.",
#        "Didn't know that existed ",
#        'Did not see the value yet and also possibly the charging battery being fault. ',
#        'My current luggage is still fine, higher cost or low quality',
#        'I do not need a new piece of luggage',
#        'I do not see the benefit and like to stick to more classy looking luggage (Rimowa aluminum) ',
#        'Not necessary', 'Cost and Weight', "Don't think I need it",
#        'I use an Air Tag to track my luggage.',
#        'Not enough money as a student', 'To expensive ',
#        'Never thought about it',
#        'I am not having problems with the luggage, even though we have unusual countries traveling too. we usually  book the slightly more reliable (and expensive) airlines. Maybe this is the reason why we do not have problems ',
#        'Never heard of it before', 'I did not know about it ',
#        "What's the point?",
#        'Because I think that I don’t travel enough to need these kind of luggages. ',
#        'I dont need it at the moment'], dtype=object)

# %%
good_existing_luggage = ['I do not see the benefit and like to stick to more classy looking luggage (Rimowa aluminum)','My current luggage is still fine, higher cost or low quality','Old suitcase is not broken','I still have perfectly good luggage and bought a small handheld scale. Works great','My old one still works','i have enough of the old ones and no need yet to buy immediately an additional new one','Don’t need new suitcase',"I have had my luggage for a long time. It still works so I don't plan on buying anything new.",'I am content with the luggage I already own','Most likely the price','I already have other luggage','I own well-working existing luggage and therefore don´t have a strong need for replacing them just to add smart elements that I could at least partially replace otherwise.','All available without smart luggage','So far I am fine with my suitcase/backpack. I travel with stuff that wouldn’t be an issue if lost.','Have not bought a new suitcase','That I already own a normal suitcase/bag',"I like my dufffle bag and I don't have the need for USB ports and stuff like that on my bag or backpack",'no need to buy a new piece of luggage since mine are fully functional. If buying a new one in a couple of years, I might consider buying smart luggage depending on the price','No need for new equipment. Might consider when I need new one','I have my suitcases and don’t need new ones','The price and the fact that I already own good quality suitcases.','I don’t need a new piece of luggage right now - my used pieces of luggage are still in a good condition','No need for a new piece of luggage','I already have the luggage I need, and buying a new one ist too expensive','I already have enough suitcases etc hence it would be an unnecessary expense',"I don't need one/ am content with the luggage I currently have","I have enough pieces, don't need anything else.",'my suitcase is fine for years, so i don‘t need a new one','My old luggage is perfectly intact','Still got my good suitcases','My luggage is to new to replace','Do not need extra luggage at the moment','Never thought about it. I am happy with the stuff I own right now (1 medium, 1 large suitcase, 1 30l backpack, 1 55l backpack)','The pieces of luggage I own still have a lot of life in them and I therefore don’t want to spend the money on a new piece of smart luggage']
too_expensive = ['To expensive','Not enough money as a student','Cost and Weight','Cost','Price/Design','Prices and already owning a lot of luggage','The price and that I dont think I need it','The fire and safety risk it still poses on board as well as the price','Money',"Didn't think about it but probably also the price","No need for it and higher cost",'Too expensive','Pricing - battery is too heavy','No need / expensive','Too expensive','Expensive and I don’t need it','Price','The need and price','High Price','Money',"Too expensive and also I don't see the point to be honest ",'Price?','Price, Design, weight of luggage']
no_full_solution = ['Only one feature per solution and too expensive for only one feature']
not_considered_yet = ['Never thought about it',"I didn't know about that type of luggage.","Haven't considered it yet, too expensive",'Never thought about',"haven't considered it, no recent purchases of new luggage",'Never thought about it, never felt like I needed something other than regular luggage','I so far have not felt like I needed it but it also has not been on my radar','I don‘t think I need it, but I haven’t given it much thought before','Don’t know if I need it','Haven‘ t think about it','Didn’t think about it yet','I just haven’t looked into those yet','Never thought of it']
no_need = ["Don't think I need it",'Not necessary','I do not need a new piece of luggage','No need for now','didn’t need anything new the last years','No need',"I didn't needed it untill now","I don't really need it",'No needed','I don‘t think it is super necessary','Don’t need that shit','No necessary','I dont See the Benefit','Don’t see the need','I never felt like I need it','I don’t need it',"Don't need yet",'No benefit',"no need to spend money on luggage because I currently own suitcases; do not use a large suitcase frequently enough to warrant spending more money on smart features; never misplaced my backpack/carry-on and always bring it with me so no real need for a tracking function; own a suitcase scale",'No need for it','For me it’s fancy but not necessary','no need so far','Don’t need it','No desperate need for it','No need for a new luggage',"Frankly, no need. I do not travel by air frequently and I normally don't lose my luggage otherwise. And I can charge my phone at home...",'Currently no need for smart luggage','Haven’t had the news for it so far','Does not feel necessary to me.',"I don't feel like it's necessary for my needs. Right now, I travel mostly with carry-on luggage, hence no need of a tracking device, and I don't fly often, so no need of a built-in scale.",'Not necessary (travelling by train)',"I don't need it for my travelling.","I have never felt the need to own it, I have other ways of covering for these needs, e.g. power banks, locks etc. I'm not opposed to it though.",'No need because of infrequent air travel','No need for new luggage.','No need for new luggage at the moment','No need','I don’t need it','Didnt see the need until now','Right now not necessary. I would purchase a smart luggage as soon as needed.']
did_not_know_existence = ['Never heard of it before','I did not know about it',"Didn't know that existed","Didn't know about it beforehand",'Hadn’t heard about it','Didnt know it exists','Never heard of it','No need so far/ didn’t know the categorie',"i didn't know something like that exists and i never felt ne need of one","Didn't know about it",'I did not know it exists','Never heard of it before','did not know it existed','I have never heard of smart luggage before','I never heard about it. I try to pack as light as possible.','I didn’t know it existed.','I did not know that they exist',"Didn't know it existed",'No need for it, did not know about it']
having_AirTags = ['I use an Air Tag to track my luggage.','Use of AirTag sufficient for my need','AirTag can do same','I have Apple AirTags']
no_existing_solution_backpack = ['Currently no smart hiking backpacks']
no_time = ['Yet no time and no offer','No time']
would_like_but_have_not_bought = ['nothing, just have not done it yet','In fact: my next piece of luggage will be smart. I just need to buy it eventually…','It’s on my list','Did not buy it yet','I would like to have one']
missing_information = ['Haven’t even really heard about it until now. So what’s preventing me: Lack of knowledge; probably price since I expect them to be rather expensive','information, what’s the benefit , price?','No trust','I rarely check in luggage.','I dont know wäre to buy','Availability and information']
bad_quality_no_trust = ['Did not see the value yet and also possibly the charging battery being fault.','Life span of the device','Restrictions from airlines',"don't trust smart devices","I don't need it, often the quality is bad"]
other = ["What's the point?",'I am not having problems with the luggage, even though we have unusual countries traveling too. we usually  book the slightly more reliable (and expensive) airlines. Maybe this is the reason why we do not have problems','No idea','Nothing','To avoid problems with airline','Upgrade after sale, e.g. Apple Location Chip','No interest','I never had any issues with my luggages.','What is a smart luggage?', 'Nothing ','no idea','Only few problems','Self-worth']

conditions = [
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, good_existing_luggage)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, too_expensive)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, no_full_solution)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, not_considered_yet)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, no_need)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, did_not_know_existence)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, having_AirTags)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, no_existing_solution_backpack)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, no_time)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, would_like_but_have_not_bought)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, missing_information)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, bad_quality_no_trust)),
    NED_Df["Prevention from Buying Smart Luggage"].str.strip().str.lower().isin(map(str.lower, other))
]


choices = ["Good Existing Luggage", "Too Expensive", "No full-feature Solution", "Not Considered Yet", "No Need", "Did Not Know Existence", "AirTags", "No Existing Suitable Solution", "No Time to Consider", "Would like to have One", "Missing Information", "Bad Quality & No Trust", "Other"]

NED_Df["Reasons for No Smart Luggage"] = np.select(conditions, choices, default="No")
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\644632067.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Reasons for No Smart Luggage"] = np.select(conditions, choices, default="No")
#      Age       Nationality Current Residence     Occupation  \
# 0     21           Belgian           Ireland       Student
# 1     22            German           Ireland       Student
# 2     25  Dual citizenship           Ireland        Student
# 3     22            German           Ireland        Student
# 4     61            German           Germany  Civilengineer
# ..   ...               ...               ...            ...
# 229   51            German             Spain          None
# 230   23            German           Germany       Student
# 231   22            German           Germany        Student
# 232   22             Swiss       Switzerland        Student
# 233   23         Sri lanka       Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                       Bulky Luggage Luggage Buying Plans (next year)  \
# 0                                No                               No
# 1                               NaN                               No
# 2                                No                               No
# 3                               NaN                               No
# 4                                No                               No
# ..                              ...                              ...
# 229                             NaN                               No
# 230                             NaN                               No
# 231                             NaN                               No
# 232                             NaN                               No
# 233  Clothes and Personal Belonging                               No
#
#     Plan-to-buy Luggage Repacking Luggage  ...  \
# 0                    No               Yes  ...
# 1                   NaN               Yes  ...
# 2                   NaN               Yes  ...
# 3                   NaN               Yes  ...
# 4                   NaN                No  ...
# ..                  ...               ...  ...
# 229                 NaN               Yes  ...
# 230                 NaN               Yes  ...
# 231                 NaN               Yes  ...
# 232                 NaN               Yes  ...
# 233                 NaN               Yes  ...
#
#                   Prevention from Buying Smart Luggage AirTag Users  \
# 0    The pieces of luggage I own still have a lot o...          Yes
# 1                     Price, Design, weight of luggage          Yes
# 2                 Currently no smart hiking backpacks            No
# 3    Only one feature per solution and too expensiv...           No
# 4                                              No time           No
# ..                                                 ...          ...
# 229                                  What's the point?           No
# 230                                                NaN           No
# 231                                                NaN          Yes
# 232  Because I think that I don’t travel enough to ...           No
# 233                       I dont need it at the moment           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range  \
# 0                                           31-45 €     16-24
# 1                                           61-75 €     16-24
# 2                                           46-60 €     25-33
# 3                                           46-60 €     16-24
# 4                                           31-45 €       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
#             Occupation Group Bought Smart Luggage Type  \
# 0                   Students                        No
# 1                   Students                        No
# 2                   Students                        No
# 3                   Students                        No
# 4    Engineering Professions                        No
# ..                       ...                       ...
# 229                  Unknown                        No
# 230                 Students                        No
# 231                 Students                        No
# 232                 Students                        No
# 233                 Students                        No
#
#     Reasons for Buying Smart Luggage Type   Reasons for No Smart Luggage
# 0                                      No          Good Existing Luggage
# 1                                      No                  Too Expensive
# 2                                      No  No Existing Suitable Solution
# 3                                      No       No full-feature Solution
# 4                                      No            No Time to Consider
# ..                                    ...                            ...
# 229                                    No                          Other
# 230                                    No                             No
# 231                                    No                             No
# 232                                    No                             No
# 233                                    No                             No
#
# [231 rows x 24 columns]

# %%
NED_Df["Reasons for No Smart Luggage"].unique()
# Out:
# array(['Good Existing Luggage', 'Too Expensive',
#        'No Existing Suitable Solution', 'No full-feature Solution',
#        'No Time to Consider', 'AirTags', 'No Need', 'Not Considered Yet',
#        'Other', 'No', 'Did Not Know Existence', 'Would like to have One',
#        'Missing Information', 'Bad Quality & No Trust'], dtype=object)

# %%
filtered_df3 = NED_Df[NED_Df["Reasons for No Smart Luggage"] != 'No']

reasons_no_smart_luggage_counts = filtered_df3["Reasons for No Smart Luggage"].value_counts()

plt.pie(reasons_no_smart_luggage_counts, labels=reasons_no_smart_luggage_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Reasons for No Smart Luggage')
plt.show()

# %%
reasons_no_smart_luggage_counts
# Out:
# No Need                          51
# Good Existing Luggage            34
# Too Expensive                    24
# Did Not Know Existence           18
# Not Considered Yet               14
# Other                            12
# Missing Information               6
# Would like to have One            5
# Bad Quality & No Trust            5
# AirTags                           4
# No Time to Consider               2
# No Existing Suitable Solution     1
# No full-feature Solution          1
# Name: Reasons for No Smart Luggage, dtype: int64

# %%
NED_Df["Travel Enhancements"].unique()
# Out:
# array(['Tracking device, smart lock, …',
#        'More comfort, easy to use suitcases, digital solutions, up-to-Date information, news, all in one travel solution,',
#        'Having to worry less about my luggage',
#        'Tracking device, scale on the luggage, name tag',
#        'Integrales scale', 'An integrated scale ',
#        'Maybe a tracking device... I used to put a spare old phone in my backpack to locate it in case of emergency. ',
#        'Tracking device , integrated scale, much safety',
#        'A tracking device sounds useful.', 'Tracking, Scale, Lock',
#        'I am perfectly happy with a bag that does not require firmware updates',
#        'integrated scale', 'tracking device, scale', 'Tracking device',
#        'Integrated scale and tracking',
#        'Better involvement of the travel company I pay',
#        'Feeling more save ', 'Tracking mostly', 'Integrated scale',
#        'Tracking device and luggage scale which I carry with me.',
#        'Np idee ', 'Weight', 'Maybe charging supply', 'Tracking ',
#        'Needs to be Light, easily movable (wheels), still waiting for a suitcase that does not take up space when stored or not in use. ',
#        'Integrated usb charging port, integrated scale', 'N/a',
#        'tracking device', 'Scale', 'Tracking device, phone charger',
#        'Nothing', 'Nothing ', 'Yes ',
#        'A built in tracking device would be great', 'track the suitcase',
#        'No', 'Using an airtag is a game changer', 'Na',
#        'More security about the whereabouts ', 'Integrated scales',
#        'Unlimited weight restriction, better wheels on trolleys', '?',
#        "Sturdy wheels that don't jam", 'a tracking device',
#        'tracking device\n', 'A good lock. Tracking device. ',
#        'A good lock and an integrated scale',
#        'integrated scale und tracking', 'Probably a tracking device',
#        'Tracking Device, Scale, sustainable materials',
#        'Tracking device ', 'Scale ',
#        'integrated scale is cool but not necessary', 'Nothing.',
#        'Scale maybe ',
#        'Easy to lift (e.g up to luggage spaces in trains)',
#        "Definitely a integrated scale so that I don't have to take a scale while traveling to avoid overweight ",
#        'Maybe less stress to loose my luggage. ', 'Integrated scale ',
#        'Not necessary',
#        'I am honestly quite satisfied without any add-on devices as you mostly find a way to eg. borrow a scale or something so that purchasing something new seems unnecessary ',
#        'nothing, stay classic', 'Knowing where my luggage is',
#        "For bigger journeys a tracking device might be helpfull as well as an integrated scale, if there isn't one available.",
#        'Integrated Scale, but only for bigger luggage', '-', nan,
#        'integrated scale, tracking device, lock, possibility to show flight information',
#        'Tracking device, integrated power bank',
#        'Tracking device, measuring device to determine whether the luggage has been subjected to violent shocks',
#        'A tracking device would be helpful especially when traveling by plane, since it occurs very often  lately that luggage gets lost ',
#        'Both might be helpful ',
#        'In general high quality of the luggage (robust materials, smooth wheels)',
#        'The packing process would be easier with a scale',
#        'None of the above. To me, it sounds like gizmos that might be good in specific situations but are mainly useless in everyday life.',
#        'Integrated scale, tracking device ', 'Tracking Devices',
#        'Tracking device, scale, USB charging port ',
#        'No different airline rules for hand luggage size, especially on backpacks',
#        'Tracking my luggage is most important for me.',
#        'Tracking device and integrated scale and measurement of luggage in terms of size',
#        'Not having to worry about weight limit when packing a reasonable amount.',
#        'both of these would. Airtags are an easy solution if people are afraid of luggage misplacement. An integrated scale is probably convenient, but most frequent travellers will already have a way to determine their luggage‘s weight.',
#        'Integrated scale would be cool but if it increases the weight considerably, then not. Tracking: def interested ',
#        'USB charger',
#        'Integrated scale sure thing but not 100% needed ; tracking device is useless from my point of view because if its lost somewhere its lost like I wont fly back just to pick up my suitcase and then fly back again',
#        'A tracking device', 'Tracking device would be nice',
#        'No Airline fees for luggage ',
#        "A luggage that is easy to transport even when it's heavy ",
#        'Luggage service at home (like baggage service in Dubai offered by Emirates) ',
#        "I haven't needed it before and don't think I will in the future",
#        'USB charging ports',
#        'I have a suitcase with an AirTag but none of the airlines I have flown with so far actually support the technology!',
#        "I'm thinking of a tracking device but more for other stuff like keys or my wallet",
#        'Don’t know',
#        'I don‘t need much…. My suitcase should hold my stuff and be distiguishable from other suitcases ',
#        'It an opportunity ',
#        'An integrated scale would probably be very helpful',
#        'Integrated Scale', 'AirTag',
#        'maybe am tracking device in case of an loss of luggage ',
#        'tracking ', 'Amazing ', 'Probably an AirTag ',
#        'Yes, tracking and integrated scale ', 'No idea',
#        'Insurance for the luggage',
#        'tracking device, integrated scale, charging port',
#        'Tracking device maybe', 'Scale, tracking, charger, lock',
#        'Not required ', 'Tracking (hence the AirTag)', 'None', 'Tracking',
#        'Less waiting time for check in luggage (check-in, waiting for check in luggage)',
#        'Tracking device & scale', 'No idea ',
#        'tracking device, integrated power bank/usb port',
#        'Integrated scale would be useful', 'Integrated power box', 'F',
#        'AirTag for sure', 'maybe a tracking device',
#        'Tracking device, integrated scale',
#        'smart storage solutions to pack more efficiently',
#        'Integrated weight measurement, probably also an integrated GPS tracking device',
#        'Tacking device, integrated scale all in one', 'Both',
#        'tracking, smart lock',
#        'I do not need further technological advancements ',
#        'Restricting myself to take less', 'luggage which carries itself',
#        "I would like to have tracking devices in all my luggage. Ideally, airlines would take these into consideration when they lose your luggage. An integrated scale sounds nice as well. But i don't want these additions to increase the weight of the luggage. ",
#        'I did not think about this topic before',
#        'selbstfahrender koffer (koffer mit Motorwelchen man mit dem Handy steuern kann) mit eingebautem Ortungsgrät',
#        'Lighter luggage', 'Scale! ', 'Free carriage of luggage',
#        'tracking device, integrated scale', '/',
#        'More locks, integrated foldable backpack, easy to access water bottle',
#        'Scale, tracking ', 'Air Tag', 'Scale, USB port for charging ',
#        'Adjustable size', 'All of the above and very good wheels ',
#        'Integrated Scale ', 'Maybe tracking', 'Both suggestions. ',
#        'great! tracking device and integrated scale', 'Less worries ',
#        'Tracking Device ', 'Not needed', 'The coziness.', 'Air Tag ',
#        'Tracking device, scale, lock', 'possibly a tracking device',
#        'Location tracking', 'vibration meter / detector',
#        'Tracking device, integrated (phone) charging station ',
#        'More reliable services from the airlines.',
#        'tracking device would be good, but would be better to be used across my multiple suitcases (I have different sizes for different lengths of trips and depending on which season I travel)',
#        'No more luggage delays',
#        'a transparent 1 liter clip-on bag for liquids',
#        'Tracking devices ', "I don't know",
#        'Integrated scale would be super. 👍 ',
#        'Integrated tracking possibilities ', 'scale',
#        "Can't think of any", 'Both of those would be helpful ',
#        'Tracking device, extra protected pocket for laptop etc., integrated scale would be useful',
#        'I think that an integrated scale would be a very useful gadget to have in a luggage since it could help save you some expenses when you luggage is to heavy. But also a tracking device would be even more important I think. Especially since luggages get stolen or lost more frequently. '],
#       dtype=object)

# %%
tracking_devices = ['Integrated tracking possibilities','Tracking devices ','tracking device would be good, but would be better to be used across my multiple suitcases (I have different sizes for different lengths of trips and depending on which season I travel)','vibration meter / detector','Location tracking','possibly a tracking device','Air Tag ','Tracking Device','Maybe tracking','Air Tag','tracking, smart lock','maybe a tracking device','AirTag for sure','Tracking','Tracking (hence the AirTag)','Tracking device maybe','Probably an AirTag','tracking','maybe am tracking device in case of an loss of luggage','AirTag',"I'm thinking of a tracking device but more for other stuff like keys or my wallet",'Tracking device would be nice','A tracking device','Tracking my luggage is most important for me.','Tracking Devices','A tracking device would be helpful especially when traveling by plane, since it occurs very often  lately that luggage gets lost','Tracking device, measuring device to determine whether the luggage has been subjected to violent shocks','Knowing where my luggage is','Maybe less stress to loose my luggage.','Tracking device','Probably a tracking device','tracking device\n', 'A good lock. Tracking device.','a tracking device','Using an airtag is a game changer','A built in tracking device would be great','track the suitcase','Tracking device, phone charger','tracking device','Tracking','Tracking mostly','tracking device, scale','Tracking device','A tracking device sounds useful.','Maybe a tracking device... I used to put a spare old phone in my backpack to locate it in case of emergency.','Tracking device, scale on the luggage, name tag','Tracking device, smart lock, …']
integrated_scale = ['scale','Integrated scale would be super. 👍 ','Integrated Scale','Scale!','Integrated scale and a better and safer closing system','Integrated scale would be useful','Integrated Scale','An integrated scale would probably be very helpful','Integrated scale sure thing but not 100% needed ; tracking device is useless from my point of view because if its lost somewhere its lost like I wont fly back just to pick up my suitcase and then fly back again','Not having to worry about weight limit when packing a reasonable amount.','The packing process would be easier with a scale','Integrated Scale, but only for bigger luggage','Integrated scale',"Definitely a integrated scale so that I don't have to take a scale while traveling to avoid overweight",'Scale maybe','Scale','A good lock and an integrated scale','Integrated scales','Scale','Weight','Integrated scale','integrated scale','Integrales scale','An integrated scale']
tracking_and_scale = ['Tracking device, scale, lock','great! tracking device and integrated scale','All of the above and very good wheels','Scale, tracking','Tacking device, integrated scale all in one','Integrated weight measurement, probably also an integrated GPS tracking device','Tracking device, integrated scale','tracking device, integrated power bank/usb port','Tracking device & scale','Scale, tracking, charger, lock','tracking device, integrated scale, charging port','Yes, tracking and integrated scale','Integrated scale would be cool but if it increases the weight considerably, then not. Tracking: def interested','both of these would. Airtags are an easy solution if people are afraid of luggage misplacement. An integrated scale is probably convenient, but most frequent travellers will already have a way to determine their luggage‘s weight.','Tracking device and integrated scale and measurement of luggage in terms of size','Tracking device, scale, USB charging port','Integrated scale, tracking device','integrated scale, tracking device, lock, possibility to show flight information',"For bigger journeys a tracking device might be helpfull as well as an integrated scale, if there isn't one available.",'Tracking Device, Scale, sustainable materials','integrated scale und tracking','Tracking, Scale, Lock','Tracking device and luggage scale which I carry with me.','Integrated scale and tracking','tracking device, integrated scale','Tracking device,integrated scale, much safety']
charging_port_power_bank = ['Tracking device, integrated (phone) charging station','Scale, USB port for charging','Integrated power box','USB charging ports','USB charger','Tracking device, integrated power bank','Integrated usb charging port, integrated scale','Maybe charging supply']
comfort_convenience = ['No more luggage delays','More reliable services from the airlines.','The coziness.','Less worries','Free carriage of luggage','Lighter luggage','luggage which carries itself','Less waiting time for check in luggage (check-in, waiting for check in luggage)','More security about the whereabouts','Feeling more save','Having to worry less about my luggage','More comfort, easy to use suitcases, digital solutions, up-to-Date information, news, all in one travel solution,']
quality_features = ['Luggage service at home (like baggage service in Dubai offered by Emirates)','In general high quality of the luggage (robust materials, smooth wheels)']
airline_compability_tracking = ["I would like to have tracking devices in all my luggage. Ideally, airlines would take these into consideration when they lose your luggage. An integrated scale sounds nice as well. But i don't want these additions to increase the weight of the luggage.",'I have a suitcase with an AirTag but none of the airlines I have flown with so far actually support the technology!']
other_not_clear = ['a transparent 1 liter clip-on bag for liquids','Both suggestions.','Adjustable size','More locks, integrated foldable backpack, easy to access water bottle','Both namens examples','selbstfahrender koffer (koffer mit Motorwelchen man mit dem Handy steuern kann) mit eingebautem Ortungsgrät','I did not think about this topic before','Restricting myself to take less','Both','smart storage solutions to pack more efficiently','Insurance for the luggage','Amazing','It an opportunity','Don’t know',"A luggage that is easy to transport even when it's heavy",'No Airline fees for luggage','No different airline rules for hand luggage size, especially on backpacks','Both might be helpful','I am honestly quite satisfied without any add-on devices as you mostly find a way to eg. borrow a scale or something so that purchasing something new seems unnecessary','Easy to lift (e.g up to luggage spaces in trains)',"Sturdy wheels that don't jam",'Unlimited weight restriction, better wheels on trolleys','Yes','Needs to be Light, easily movable (wheels), still waiting for a suitcase that does not take up space when stored or not in use.','Better involvement of the travel company I pay']
no_enhancements_needed = ["Can't think of any","I don't know",'Not needed','I do not need further technological advancements ','No idea ','None','Not required','No idea','I don‘t need much…. My suitcase should hold my stuff and be distiguishable from other suitcases',"I haven't needed it before and don't think I will in the future",'None of the above. To me, it sounds like gizmos that might be good in specific situations but are mainly useless in everyday life.','-','nothing, stay classic','Not necessary','integrated scale is cool but not necessary', 'Nothing.','?','Na','No','Nothing','Nothing ','N/a','Np idee','I am perfectly happy with a bag that does not require firmware updates']

conditions = [
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, tracking_devices)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, integrated_scale)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, tracking_and_scale)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, charging_port_power_bank)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, comfort_convenience)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, quality_features)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, airline_compability_tracking)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, other_not_clear)),
    NED_Df["Travel Enhancements"].str.strip().str.lower().isin(map(str.lower, no_enhancements_needed))
]


choices = ["Tracking", "Integrated Scale", "Tracking and Integrated Scale","Charging Port", "Comfort & Convenience", "Quality Features", "Airline Support by Tracking", "No enhancements Needed","Other"]

NED_Df["Travel Enhancement Groups"] = np.select(conditions, choices, default="NaN")
NED_Df
# Out:
# C:\Users\CZ\AppData\Local\Temp\ipykernel_47980\2535207209.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NED_Df["Travel Enhancement Groups"] = np.select(conditions, choices, default="NaN")
#      Age       Nationality Current Residence     Occupation  \
# 0     21           Belgian           Ireland       Student
# 1     22            German           Ireland       Student
# 2     25  Dual citizenship           Ireland        Student
# 3     22            German           Ireland        Student
# 4     61            German           Germany  Civilengineer
# ..   ...               ...               ...            ...
# 229   51            German             Spain          None
# 230   23            German           Germany       Student
# 231   22            German           Germany        Student
# 232   22             Swiss       Switzerland        Student
# 233   23         Sri lanka       Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                       Bulky Luggage Luggage Buying Plans (next year)  \
# 0                                No                               No
# 1                               NaN                               No
# 2                                No                               No
# 3                               NaN                               No
# 4                                No                               No
# ..                              ...                              ...
# 229                             NaN                               No
# 230                             NaN                               No
# 231                             NaN                               No
# 232                             NaN                               No
# 233  Clothes and Personal Belonging                               No
#
#     Plan-to-buy Luggage Repacking Luggage  ... AirTag Users  \
# 0                    No               Yes  ...          Yes
# 1                   NaN               Yes  ...          Yes
# 2                   NaN               Yes  ...           No
# 3                   NaN               Yes  ...           No
# 4                   NaN                No  ...           No
# ..                  ...               ...  ...          ...
# 229                 NaN               Yes  ...           No
# 230                 NaN               Yes  ...           No
# 231                 NaN               Yes  ...          Yes
# 232                 NaN               Yes  ...           No
# 233                 NaN               Yes  ...           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range  \
# 0                                           31-45 €     16-24
# 1                                           61-75 €     16-24
# 2                                           46-60 €     25-33
# 3                                           46-60 €     16-24
# 4                                           31-45 €       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
#             Occupation Group Bought Smart Luggage Type  \
# 0                   Students                        No
# 1                   Students                        No
# 2                   Students                        No
# 3                   Students                        No
# 4    Engineering Professions                        No
# ..                       ...                       ...
# 229                  Unknown                        No
# 230                 Students                        No
# 231                 Students                        No
# 232                 Students                        No
# 233                 Students                        No
#
#     Reasons for Buying Smart Luggage Type   Reasons for No Smart Luggage  \
# 0                                      No          Good Existing Luggage
# 1                                      No                  Too Expensive
# 2                                      No  No Existing Suitable Solution
# 3                                      No       No full-feature Solution
# 4                                      No            No Time to Consider
# ..                                    ...                            ...
# 229                                    No                          Other
# 230                                    No                             No
# 231                                    No                             No
# 232                                    No                             No
# 233                                    No                             No
#
#     Travel Enhancement Groups
# 0                    Tracking
# 1       Comfort & Convenience
# 2       Comfort & Convenience
# 3                    Tracking
# 4            Integrated Scale
# ..                        ...
# 229                     Other
# 230                       NaN
# 231                       NaN
# 232                       NaN
# 233          Integrated Scale
#
# [231 rows x 25 columns]

# %%
travel_enhancements_counts = NED_Df["Travel Enhancement Groups"].value_counts()

plt.pie(travel_enhancements_counts, labels=travel_enhancements_counts.index, autopct='%1.1f%%', textprops={'fontsize':6})
plt.title('Travel Enhancements')
plt.show()

# %%
travel_enhancements_counts
# Out:
# Tracking                         77
# Integrated Scale                 40
# Other                            28
# Tracking and Integrated Scale    26
# No enhancements Needed           26
# Comfort & Convenience            12
# NaN                              10
# Charging Port                     8
# Quality Features                  2
# Airline Support by Tracking       2
# Name: Travel Enhancement Groups, dtype: int64

# %%
NED_Df
# Out:
#      Age       Nationality Current Residence     Occupation  \
# 0     21           Belgian           Ireland       Student
# 1     22            German           Ireland       Student
# 2     25  Dual citizenship           Ireland        Student
# 3     22            German           Ireland        Student
# 4     61            German           Germany  Civilengineer
# ..   ...               ...               ...            ...
# 229   51            German             Spain          None
# 230   23            German           Germany       Student
# 231   22            German           Germany        Student
# 232   22             Swiss       Switzerland        Student
# 233   23         Sri lanka       Switzerland        Student
#
#         Travel per year                                     Travel Luggage  \
# 0    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 1    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 2                   4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 3    More than 15 times  Suitcase (carry-on);Suitcase (check-in luggage...
# 4                   1-3             Suitcase (check-in luggage);Laptop bag
# ..                  ...                                                ...
# 229                 4-6  Suitcase (carry-on);Duffel bag/Weekender;Handb...
# 230               10-15  Suitcase (carry-on);Backpack (below 50 litre);...
# 231                 4-6  Suitcase (carry-on);Suitcase (check-in luggage...
# 232                 1-3  Suitcase (check-in luggage);Duffel bag/Weekend...
# 233                 1-3                        Suitcase (check-in luggage)
#
#                       Bulky Luggage Luggage Buying Plans (next year)  \
# 0                                No                               No
# 1                               NaN                               No
# 2                                No                               No
# 3                               NaN                               No
# 4                                No                               No
# ..                              ...                              ...
# 229                             NaN                               No
# 230                             NaN                               No
# 231                             NaN                               No
# 232                             NaN                               No
# 233  Clothes and Personal Belonging                               No
#
#     Plan-to-buy Luggage Repacking Luggage  ... AirTag Users  \
# 0                    No               Yes  ...          Yes
# 1                   NaN               Yes  ...          Yes
# 2                   NaN               Yes  ...           No
# 3                   NaN               Yes  ...           No
# 4                   NaN                No  ...           No
# ..                  ...               ...  ...          ...
# 229                 NaN               Yes  ...           No
# 230                 NaN               Yes  ...           No
# 231                 NaN               Yes  ...          Yes
# 232                 NaN               Yes  ...           No
# 233                 NaN               Yes  ...           No
#
#                                    Travel Enhancements  \
# 0                       Tracking device, smart lock, …
# 1    More comfort, easy to use suitcases, digital s...
# 2                Having to worry less about my luggage
# 3      Tracking device, scale on the luggage, name tag
# 4                                     Integrales scale
# ..                                                 ...
# 229                                 Can't think of any
# 230                    Both of those would be helpful
# 231  Tracking device, extra protected pocket for la...
# 232  I think that an integrated scale would be a ve...
# 233                                   Integrated scale
#
#                        Biggest travel Concerns & Fears  \
# 0    Loosing your luggage;Misplaced luggage (by the...
# 1    Loosing your luggage;Damaged luggage;Overweigh...
# 2    Loosing your luggage;Misplaced luggage (by the...
# 3    Loosing your luggage;Misplaced luggage (by the...
# 4                      Damaged luggage;Overweight fees
# ..                                                 ...
# 229                    Damaged luggage;Overweight fees
# 230                      Luggage theft;Overweight fees
# 231  Loosing your luggage;Damaged luggage;Luggage m...
# 232  Loosing your luggage;Misplaced luggage (by the...
# 233                               Loosing your luggage
#
#     Price Sensitivity for a Add-on Digital Solution Age Range  \
# 0                                           31-45 €     16-24
# 1                                           61-75 €     16-24
# 2                                           46-60 €     25-33
# 3                                           46-60 €     16-24
# 4                                           31-45 €       >52
# ..                                              ...       ...
# 229                 I would not buy such a solution     43-51
# 230                                         31-45 €     16-24
# 231                                         16-30 €     16-24
# 232                                        76-100 €     16-24
# 233                                         31-45 €     16-24
#
#             Occupation Group Bought Smart Luggage Type  \
# 0                   Students                        No
# 1                   Students                        No
# 2                   Students                        No
# 3                   Students                        No
# 4    Engineering Professions                        No
# ..                       ...                       ...
# 229                  Unknown                        No
# 230                 Students                        No
# 231                 Students                        No
# 232                 Students                        No
# 233                 Students                        No
#
#     Reasons for Buying Smart Luggage Type   Reasons for No Smart Luggage  \
# 0                                      No          Good Existing Luggage
# 1                                      No                  Too Expensive
# 2                                      No  No Existing Suitable Solution
# 3                                      No       No full-feature Solution
# 4                                      No            No Time to Consider
# ..                                    ...                            ...
# 229                                    No                          Other
# 230                                    No                             No
# 231                                    No                             No
# 232                                    No                             No
# 233                                    No                             No
#
#     Travel Enhancement Groups
# 0                    Tracking
# 1       Comfort & Convenience
# 2       Comfort & Convenience
# 3                    Tracking
# 4            Integrated Scale
# ..                        ...
# 229                     Other
# 230                       NaN
# 231                       NaN
# 232                       NaN
# 233          Integrated Scale
#
# [231 rows x 25 columns]

# %%
plt.scatter(NED_Df["Age"], NED_Df["Price Sensitivity for a Add-on Digital Solution"])
plt.title('Correlation between Age and Price Sensitivity')
plt.show()

# %%
NED_Df.to_csv('C:/CarolineZiegler/Studium_DCU/8. Semester/Business Analytics Portfolio/Portfolio/02_Uni Projects/outFile.csv', index=False)
